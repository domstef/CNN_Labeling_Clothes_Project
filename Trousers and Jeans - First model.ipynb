# %% [markdown]
# # Trousers and jeans model

# %% [markdown]
# 0 - Male trousers
# 1 - Female trousers
# 2 - Male jeans
# 3 - Female jeans
#
# This is a simple model - Conv2D -> Flatten - > Dense

# %% [markdown]
# # Import relevant libraries

# %%
import io
import itertools
import numpy as np
import sklearn.metrics
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the data

# %%
data_train = np.load(r"data/Trousers & Jeans - All - Train.npz")
data_validation = np.load(r"data/Trousers & Jeans - All - Validation.npz")
data_test = np.load(r"data/Trousers & Jeans - All - Test.npz")

print("Data train files: {}".format(data_train.files))
print("Size of the images: {}".format(data_train['images'].shape))
print("Size of the labels: {}".format(data_train['labels'].shape))
print("Unique values of the labels: {}".format(np.unique(data_train['labels'])))
n = np.random.randint(0, 4002)
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(data_train['images'][n])
print("The label of {}'th image is {}".format(n, data_train['labels'][n]))

n = np.random.randint(0, 4002)
ax2.imshow(data_train['images'][n])
print("The label of {}'th image is {}".format(n, data_train['labels'][n]))
# Out:
# Data train files: ['images', 'labels', 'genders']
# Size of the images: (4004, 120, 90, 3)
# Size of the labels: (4004,)
# Unique values of the labels: [0 1 2 3]
# The label of 2617'th image is 2
# The label of 3076'th image is 0

# %%
images_train = data_train['images']
labels_train = data_train['labels']

images_val = data_validation['images']
labels_val = data_validation['labels']

images_test = data_test['images']
labels_test = data_test['labels']

# %%
images_train = images_train/255.0
images_val = images_val/255.0
images_test = images_test/255.0

# %% [markdown]
# # Training the models

# %%
EPOCHS = 15
BATCH_SIZE = 64 #power of 2

HP_FILTER_SIZE = hp.HParam("filter_size", hp.Discrete([3,5,7]))
HP_FILTER_NUM = hp.HParam("filter_number", hp.Discrete([32, 64, 96, 128]))

METRIC_ACCURACY = "accuracy"

with tf.summary.create_file_writer(r'Logs/Model 3_1/hparams_tuning/').as_default():
    hp.hparams_config(
        hparams=[HP_FILTER_SIZE, HP_FILTER_NUM],
        metrics=[hp.Metric(METRIC_ACCURACY, display_name="Accuracy")])

# %%
def plot_confusion_matrix(cm, class_names):
    """
    Returns a matplotlib figure containing the plotted confusion matrix.

    Args:
        cm (array, shape = [n, n]): a confusion matrix of integer classes
        class_names (array, shape = [n]): String names of the integer classes
    """
    figure = plt.figure(figsize=(12, 12))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    # Normalize the confusion matrix.
    cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return figure

# %%
def plot_to_image(figure):
    """Converts the matplotlib plot specified by 'figure' to a PNG image and
    returns it. The supplied figure is closed and inaccessible after this call."""
    # Save the plot to a PNG in memory.
    buf = io.BytesIO()
    plt.savefig(buf, format='png')
    # Closing the figure prevents it from being displayed directly inside
    # the notebook.
    plt.close(figure)
    buf.seek(0)
    # Convert PNG buffer to TF image
    image = tf.image.decode_png(buf.getvalue(), channels=4)
    # Add the batch dimension
    image = tf.expand_dims(image, 0)
    return image

# %%
def train_test_model(hparams, session_num):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(hparams[HP_FILTER_NUM],
                              hparams[HP_FILTER_SIZE],
                              activation = "relu",
                              input_shape = (120,90,3)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(4)
    ])
    
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    model.compile(optimizer="adam", loss=loss_fn, metrics=['accuracy'])
    

    log_dir = "Logs\\Model 3_1\\fit\\" + "run {}".format(session_num)
    
  
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')
    
    def log_confusion_matrix(epoch, logs):
        
        test_pred_raw = model.predict(images_val)
        test_pred = np.argmax(test_pred_raw, axis=1)

        
        cm = sklearn.metrics.confusion_matrix(labels_val, test_pred)
       
        figure = plot_confusion_matrix(cm, class_names=['Trousers Male', 'Jeans Male', 'Trousers Female', 'Jeans Female'])
        cm_image = plot_to_image(figure)

        
        with file_writer_cm.as_default():
            tf.summary.image("Confusion Matrix", cm_image, step=epoch)
    
    
    
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch=0)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)
    

    
 
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor = 'val_loss',
        mode = 'auto',
        min_delta = 0,
        patience = 2,
        verbose = 0, 
        restore_best_weights = True
    )
    

    model.fit(
        images_train,
        labels_train,
        epochs = EPOCHS,
        batch_size = BATCH_SIZE,
        callbacks = [tensorboard_callback, cm_callback, early_stopping],
        validation_data = (images_val,labels_val),
        verbose = 2
    )
    
    

    _, accuracy = model.evaluate(images_val,labels_val)
    

    model.save(r"saved_models\Model 3_1\Run-{}".format(session_num))
    
    return accuracy

# %%
def run(log_dir, hparams, session_num):
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step = 1)

# %%
session_num = 1

for filter_size in HP_FILTER_SIZE.domain.values:
    for filter_num in HP_FILTER_NUM.domain.values:

        hparams = {
            HP_FILTER_SIZE: filter_size,
            HP_FILTER_NUM: filter_num
        }

        run_name = "run-%d" % session_num
        print('--- Starting trial: %s' % run_name)
        print({h.name: hparams[h] for h in hparams})
        run('Logs/Model 3_1/hparam_tuning/' + run_name, hparams, session_num)

        session_num += 1
# Out:
# --- Starting trial: run-1
# {'filter_size': 3, 'filter_number': 32}
# Epoch 1/15
# 63/63 - 5s - loss: 8.4150 - accuracy: 0.3939 - val_loss: 1.1012 - val_accuracy: 0.5640
# Epoch 2/15
# 63/63 - 4s - loss: 0.9330 - accuracy: 0.6341 - val_loss: 0.9854 - val_accuracy: 0.6060
# Epoch 3/15
# 63/63 - 5s - loss: 0.7700 - accuracy: 0.7008 - val_loss: 0.9255 - val_accuracy: 0.5860
# Epoch 4/15
# 63/63 - 8s - loss: 0.6395 - accuracy: 0.7562 - val_loss: 0.8566 - val_accuracy: 0.6820
# Epoch 5/15
# 63/63 - 7s - loss: 0.5459 - accuracy: 0.7905 - val_loss: 0.9104 - val_accuracy: 0.6220
# Epoch 6/15
# 63/63 - 9s - loss: 0.5152 - accuracy: 0.8099 - val_loss: 0.8383 - val_accuracy: 0.6860
# Epoch 7/15
# 63/63 - 11s - loss: 0.4658 - accuracy: 0.8364 - val_loss: 0.8280 - val_accuracy: 0.6960
# Epoch 8/15
# 63/63 - 11s - loss: 0.4356 - accuracy: 0.8427 - val_loss: 0.8424 - val_accuracy: 0.6960
# Epoch 9/15
# 63/63 - 13s - loss: 0.3969 - accuracy: 0.8546 - val_loss: 1.0540 - val_accuracy: 0.6700
# 16/16 [==============================] - 1s 40ms/step - loss: 0.8280 - accuracy: 0.6960
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-1\assets
# --- Starting trial: run-2
# {'filter_size': 3, 'filter_number': 64}
# Epoch 1/15
# 63/63 - 25s - loss: 4.6601 - accuracy: 0.4768 - val_loss: 1.0251 - val_accuracy: 0.5920
# Epoch 2/15
# 63/63 - 20s - loss: 0.8643 - accuracy: 0.6449 - val_loss: 0.9444 - val_accuracy: 0.6020
# Epoch 3/15
# 63/63 - 21s - loss: 0.7076 - accuracy: 0.7220 - val_loss: 0.8650 - val_accuracy: 0.6660
# Epoch 4/15
# 63/63 - 22s - loss: 0.6287 - accuracy: 0.7520 - val_loss: 0.9540 - val_accuracy: 0.6380
# Epoch 5/15
# 63/63 - 21s - loss: 0.5711 - accuracy: 0.7802 - val_loss: 0.8127 - val_accuracy: 0.7080
# Epoch 6/15
# 63/63 - 13s - loss: 0.4873 - accuracy: 0.8254 - val_loss: 0.8578 - val_accuracy: 0.7060
# Epoch 7/15
# 63/63 - 13s - loss: 0.4611 - accuracy: 0.8312 - val_loss: 0.9322 - val_accuracy: 0.6440
# 16/16 [==============================] - 1s 33ms/step - loss: 0.8127 - accuracy: 0.7080
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-2\assets
# --- Starting trial: run-3
# {'filter_size': 3, 'filter_number': 96}
# Epoch 1/15
# 63/63 - 28s - loss: 6.6141 - accuracy: 0.4443 - val_loss: 1.0446 - val_accuracy: 0.5820
# Epoch 2/15
# 63/63 - 27s - loss: 0.8884 - accuracy: 0.6633 - val_loss: 1.2613 - val_accuracy: 0.4860
# Epoch 3/15
# 63/63 - 27s - loss: 0.8988 - accuracy: 0.6513 - val_loss: 0.9780 - val_accuracy: 0.6120
# Epoch 4/15
# 63/63 - 27s - loss: 0.7383 - accuracy: 0.7108 - val_loss: 0.9047 - val_accuracy: 0.6560
# Epoch 5/15
# 63/63 - 28s - loss: 0.6264 - accuracy: 0.7667 - val_loss: 0.8752 - val_accuracy: 0.6620
# Epoch 6/15
# 63/63 - 28s - loss: 0.5102 - accuracy: 0.8114 - val_loss: 0.8438 - val_accuracy: 0.6880
# Epoch 7/15
# 63/63 - 29s - loss: 0.4659 - accuracy: 0.8297 - val_loss: 0.8090 - val_accuracy: 0.7040
# Epoch 8/15
# 63/63 - 25s - loss: 0.3998 - accuracy: 0.8569 - val_loss: 0.8752 - val_accuracy: 0.6900
# Epoch 9/15
# 63/63 - 26s - loss: 0.4220 - accuracy: 0.8479 - val_loss: 0.8820 - val_accuracy: 0.6740
# 16/16 [==============================] - 1s 71ms/step - loss: 0.8090 - accuracy: 0.7040
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-3\assets
# --- Starting trial: run-4
# {'filter_size': 3, 'filter_number': 128}
# Epoch 1/15
# 63/63 - 41s - loss: 4.9502 - accuracy: 0.4578 - val_loss: 1.1980 - val_accuracy: 0.5020
# Epoch 2/15
# 63/63 - 25s - loss: 0.8660 - accuracy: 0.6646 - val_loss: 0.8649 - val_accuracy: 0.6760
# Epoch 3/15
# 63/63 - 25s - loss: 0.7156 - accuracy: 0.7235 - val_loss: 0.8928 - val_accuracy: 0.6420
# Epoch 4/15
# 63/63 - 35s - loss: 0.6457 - accuracy: 0.7493 - val_loss: 0.8540 - val_accuracy: 0.6740
# Epoch 5/15
# 63/63 - 37s - loss: 0.6239 - accuracy: 0.7645 - val_loss: 0.8715 - val_accuracy: 0.6640
# Epoch 6/15
# 63/63 - 44s - loss: 0.4905 - accuracy: 0.8227 - val_loss: 0.8768 - val_accuracy: 0.6880
# 16/16 [==============================] - 2s 93ms/step - loss: 0.8540 - accuracy: 0.6740
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-4\assets
# --- Starting trial: run-5
# {'filter_size': 5, 'filter_number': 32}
# Epoch 1/15
# 63/63 - 18s - loss: 1.6975 - accuracy: 0.4993 - val_loss: 1.0559 - val_accuracy: 0.5760
# Epoch 2/15
# 63/63 - 15s - loss: 0.9075 - accuracy: 0.6546 - val_loss: 0.9276 - val_accuracy: 0.6200
# Epoch 3/15
# 63/63 - 15s - loss: 0.7285 - accuracy: 0.7163 - val_loss: 0.8425 - val_accuracy: 0.6400
# Epoch 4/15
# 63/63 - 15s - loss: 0.6667 - accuracy: 0.7460 - val_loss: 0.8208 - val_accuracy: 0.6900
# Epoch 5/15
# 63/63 - 15s - loss: 0.5834 - accuracy: 0.7652 - val_loss: 0.8669 - val_accuracy: 0.6600
# Epoch 6/15
# 63/63 - 16s - loss: 0.5378 - accuracy: 0.7922 - val_loss: 0.8439 - val_accuracy: 0.6980
# 16/16 [==============================] - 1s 29ms/step - loss: 0.8208 - accuracy: 0.6900
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-5\assets
# --- Starting trial: run-6
# {'filter_size': 5, 'filter_number': 64}
# Epoch 1/15
# 63/63 - 28s - loss: 3.3400 - accuracy: 0.4568 - val_loss: 1.1102 - val_accuracy: 0.5520
# Epoch 2/15
# 63/63 - 22s - loss: 0.9319 - accuracy: 0.6391 - val_loss: 1.0031 - val_accuracy: 0.6100
# Epoch 3/15
# 63/63 - 26s - loss: 0.7908 - accuracy: 0.6936 - val_loss: 0.9061 - val_accuracy: 0.6720
# Epoch 4/15
# 63/63 - 28s - loss: 0.7381 - accuracy: 0.7163 - val_loss: 0.9315 - val_accuracy: 0.6580
# Epoch 5/15
# 63/63 - 26s - loss: 0.6524 - accuracy: 0.7480 - val_loss: 0.8770 - val_accuracy: 0.6640
# Epoch 6/15
# 63/63 - 28s - loss: 0.6454 - accuracy: 0.7478 - val_loss: 0.9050 - val_accuracy: 0.6940
# Epoch 7/15
# 63/63 - 27s - loss: 0.5849 - accuracy: 0.7687 - val_loss: 0.8870 - val_accuracy: 0.6900
# 16/16 [==============================] - 1s 32ms/step - loss: 0.8770 - accuracy: 0.6640
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-6\assets
# --- Starting trial: run-7
# {'filter_size': 5, 'filter_number': 96}
# Epoch 1/15
# 63/63 - 40s - loss: 3.7370 - accuracy: 0.4773 - val_loss: 1.4672 - val_accuracy: 0.4040
# Epoch 2/15
# 63/63 - 33s - loss: 0.9327 - accuracy: 0.6329 - val_loss: 0.9183 - val_accuracy: 0.6280
# Epoch 3/15
# 63/63 - 37s - loss: 0.7572 - accuracy: 0.7000 - val_loss: 0.8410 - val_accuracy: 0.6740
# Epoch 4/15
# 63/63 - 97s - loss: 0.7274 - accuracy: 0.7220 - val_loss: 0.8844 - val_accuracy: 0.6440
# Epoch 5/15
# 63/63 - 38s - loss: 0.7005 - accuracy: 0.7378 - val_loss: 0.8977 - val_accuracy: 0.6540
# 16/16 [==============================] - 1s 68ms/step - loss: 0.8410 - accuracy: 0.6740
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-7\assets
# --- Starting trial: run-8
# {'filter_size': 5, 'filter_number': 128}
# Epoch 1/15
# 63/63 - 53s - loss: 5.4165 - accuracy: 0.4813 - val_loss: 1.0666 - val_accuracy: 0.5980
# Epoch 2/15
# 63/63 - 51s - loss: 0.9515 - accuracy: 0.6149 - val_loss: 1.0076 - val_accuracy: 0.5940
# Epoch 3/15
# 63/63 - 53s - loss: 0.8885 - accuracy: 0.6489 - val_loss: 0.9366 - val_accuracy: 0.6280
# Epoch 4/15
# 63/63 - 48s - loss: 0.7832 - accuracy: 0.6906 - val_loss: 0.9155 - val_accuracy: 0.6680
# Epoch 5/15
# 63/63 - 49s - loss: 0.7122 - accuracy: 0.7230 - val_loss: 0.9228 - val_accuracy: 0.6540
# Epoch 6/15
# 63/63 - 54s - loss: 0.6726 - accuracy: 0.7380 - val_loss: 0.9257 - val_accuracy: 0.6160
# 16/16 [==============================] - 2s 93ms/step - loss: 0.9155 - accuracy: 0.6680
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-8\assets
# --- Starting trial: run-9
# {'filter_size': 7, 'filter_number': 32}
# Epoch 1/15
# 63/63 - 29s - loss: 2.2352 - accuracy: 0.4930 - val_loss: 1.0311 - val_accuracy: 0.5920
# Epoch 2/15
# 63/63 - 24s - loss: 1.0392 - accuracy: 0.5962 - val_loss: 1.1103 - val_accuracy: 0.5360
# Epoch 3/15
# 63/63 - 25s - loss: 0.9343 - accuracy: 0.6181 - val_loss: 1.0083 - val_accuracy: 0.5840
# Epoch 4/15
# 63/63 - 24s - loss: 0.8377 - accuracy: 0.6573 - val_loss: 0.9053 - val_accuracy: 0.6420
# Epoch 5/15
# 63/63 - 18s - loss: 0.7705 - accuracy: 0.6928 - val_loss: 0.9018 - val_accuracy: 0.6680
# Epoch 6/15
# 63/63 - 25s - loss: 0.7545 - accuracy: 0.6953 - val_loss: 0.8701 - val_accuracy: 0.6740
# Epoch 7/15
# 63/63 - 24s - loss: 0.6400 - accuracy: 0.7555 - val_loss: 0.9407 - val_accuracy: 0.6560
# Epoch 8/15
# 63/63 - 23s - loss: 0.6228 - accuracy: 0.7567 - val_loss: 0.8918 - val_accuracy: 0.6840
# 16/16 [==============================] - 1s 40ms/step - loss: 0.8701 - accuracy: 0.6740
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-9\assets
# --- Starting trial: run-10
# {'filter_size': 7, 'filter_number': 64}
# Epoch 1/15
# 63/63 - 42s - loss: 2.8837 - accuracy: 0.4730 - val_loss: 1.0698 - val_accuracy: 0.5920
# Epoch 2/15
# 63/63 - 37s - loss: 0.9835 - accuracy: 0.6144 - val_loss: 1.0410 - val_accuracy: 0.5980
# Epoch 3/15
# 63/63 - 38s - loss: 0.8817 - accuracy: 0.6499 - val_loss: 0.9390 - val_accuracy: 0.6460
# Epoch 4/15
# 63/63 - 24s - loss: 0.8213 - accuracy: 0.6703 - val_loss: 0.8984 - val_accuracy: 0.6600
# Epoch 5/15
# 63/63 - 24s - loss: 0.7507 - accuracy: 0.6986 - val_loss: 0.9336 - val_accuracy: 0.6500
# Epoch 6/15
# 63/63 - 38s - loss: 0.7873 - accuracy: 0.7000 - val_loss: 0.8715 - val_accuracy: 0.6540
# Epoch 7/15
# 63/63 - 36s - loss: 0.6741 - accuracy: 0.7380 - val_loss: 0.8651 - val_accuracy: 0.6660
# Epoch 8/15
# 63/63 - 36s - loss: 0.6454 - accuracy: 0.7542 - val_loss: 0.9673 - val_accuracy: 0.6300
# Epoch 9/15
# 63/63 - 33s - loss: 0.6152 - accuracy: 0.7570 - val_loss: 0.9065 - val_accuracy: 0.6800
# 16/16 [==============================] - 1s 66ms/step - loss: 0.8651 - accuracy: 0.6660
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-10\assets
# --- Starting trial: run-11
# {'filter_size': 7, 'filter_number': 96}
# Epoch 1/15
# 63/63 - 49s - loss: 3.5119 - accuracy: 0.4588 - val_loss: 1.0749 - val_accuracy: 0.5900
# Epoch 2/15
# 63/63 - 50s - loss: 0.9393 - accuracy: 0.6181 - val_loss: 0.9279 - val_accuracy: 0.6300
# Epoch 3/15
# 63/63 - 51s - loss: 0.8299 - accuracy: 0.6746 - val_loss: 1.0396 - val_accuracy: 0.5900
# Epoch 4/15
# 63/63 - 36s - loss: 0.7844 - accuracy: 0.6966 - val_loss: 0.8851 - val_accuracy: 0.6540
# Epoch 5/15
# 63/63 - 37s - loss: 0.7459 - accuracy: 0.7105 - val_loss: 0.8878 - val_accuracy: 0.6540
# Epoch 6/15
# 63/63 - 50s - loss: 0.6851 - accuracy: 0.7303 - val_loss: 0.8534 - val_accuracy: 0.6740
# Epoch 7/15
# 63/63 - 49s - loss: 0.6740 - accuracy: 0.7398 - val_loss: 0.8936 - val_accuracy: 0.6420
# Epoch 8/15
# 63/63 - 52s - loss: 0.6201 - accuracy: 0.7620 - val_loss: 0.9738 - val_accuracy: 0.6440
# 16/16 [==============================] - 1s 75ms/step - loss: 0.8534 - accuracy: 0.6740
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-11\assets
# --- Starting trial: run-12
# {'filter_size': 7, 'filter_number': 128}
# Epoch 1/15
# 63/63 - 71s - loss: 3.0319 - accuracy: 0.4685 - val_loss: 1.0300 - val_accuracy: 0.6020
# Epoch 2/15
# 63/63 - 69s - loss: 0.9553 - accuracy: 0.6114 - val_loss: 0.9964 - val_accuracy: 0.6120
# Epoch 3/15
# 63/63 - 70s - loss: 0.9661 - accuracy: 0.6094 - val_loss: 1.0909 - val_accuracy: 0.4980
# Epoch 4/15
# 63/63 - 64s - loss: 1.0338 - accuracy: 0.5917 - val_loss: 1.0378 - val_accuracy: 0.5980
# 16/16 [==============================] - 2s 101ms/step - loss: 0.9964 - accuracy: 0.6120
# INFO:tensorflow:Assets written to: saved_models\Model 3_1\Run-12\assets

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 3_1/hparam_tuning"
# Out:
#       <iframe id="tensorboard-frame-2573f610fc1d8ea4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2573f610fc1d8ea4");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
