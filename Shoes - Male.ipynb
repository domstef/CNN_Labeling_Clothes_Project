# %% [markdown]
# # Shoes model

# %% [markdown]
# 0  - Boots
# 1 - Trainers/Sneakers
# 2 - Sandals/Flip flops/Slippers
# 3 - Formal shoes
# 4 - Others

# %% [markdown]
# # Import relevant libraries

# %%
import io
import itertools
import numpy as np
import sklearn.metrics
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the data

# %%
data_train = np.load(r"data/Shoes - Male - Train.npz")
data_validation = np.load(r"data/Shoes - Male - Validation.npz")
data_test = np.load(r"data/Shoes - Male - Test.npz")

print("Data train files: {}".format(data_train.files))
print("Size of the images: {}".format(data_train['images'].shape))
print("Size of the labels: {}".format(data_train['labels'].shape))
print("Unique values of the labels: {}".format(np.unique(data_train['labels'])))
n = np.random.randint(0, 2073)
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(data_train['images'][n])
print("The label of {}'th image is {}".format(n, data_train['labels'][n]))

n = np.random.randint(0, 2073)
ax2.imshow(data_train['images'][n])
print("The label of {}'th image is {}".format(n, data_train['labels'][n]))
n = np.random.randint(0, 2073)
ax2.imshow(data_train['images'][n])
print("The label of {}'th image is {}".format(n, data_train['labels'][n]))
n = np.random.randint(0, 2073)
ax2.imshow(data_train['images'][n])
print("The label of {}'th image is {}".format(n, data_train['labels'][n]))
# Out:
# Data train files: ['images', 'labels']
# Size of the images: (2073, 120, 90, 3)
# Size of the labels: (2073,)
# Unique values of the labels: [0 1 2 3 4]
# The label of 517'th image is 4
# The label of 1119'th image is 1
# The label of 451'th image is 0
# The label of 590'th image is 1

# %%
images_train = data_train['images']
labels_train = data_train['labels']

images_val = data_validation['images']
labels_val = data_validation['labels']

images_test = data_test['images']
labels_test = data_test['labels']

# %%
images_train = images_train/255.0
images_val = images_val/255.0
images_test = images_test/255.0

# %% [markdown]
# # Training the models

# %%
EPOCHS = 15
BATCH_SIZE = 64 #power of 2

HP_FILTER_SIZE_1 = hp.HParam('filter_size_1', hp.Discrete([3,5,7]))
HP_FILTER_NUM = hp.HParam('filters_number', hp.Discrete([32,64,96]))
HP_FILTER_SIZE_2 = hp.HParam('filter_size_2', hp.Discrete([3,5]))
HP_DENSE_SIZE = hp.HParam('dense_size', hp.Discrete([256,512]))

METRIC_ACCURACY = "accuracy"

with tf.summary.create_file_writer(r'Logs/Model 5_2/hparam_tuning/').as_default():
    hp.hparams_config(
        hparams=[HP_FILTER_SIZE_1, HP_FILTER_NUM, HP_FILTER_SIZE_2, HP_DENSE_SIZE],
        metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
    )

# %%
def plot_confusion_matrix(cm, class_names):
    """
    Returns a matplotlib figure containing the plotted confusion matrix.

    Args:
        cm (array, shape = [n, n]): a confusion matrix of integer classes
        class_names (array, shape = [n]): String names of the integer classes
    """
    figure = plt.figure(figsize=(12, 12))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    # Normalize the confusion matrix.
    cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return figure

# %%
def plot_to_image(figure):
    """Converts the matplotlib plot specified by 'figure' to a PNG image and
    returns it. The supplied figure is closed and inaccessible after this call."""
    # Save the plot to a PNG in memory.
    buf = io.BytesIO()
    plt.savefig(buf, format='png')
    # Closing the figure prevents it from being displayed directly inside
    # the notebook.
    plt.close(figure)
    buf.seek(0)
    # Convert PNG buffer to TF image
    image = tf.image.decode_png(buf.getvalue(), channels=4)
    # Add the batch dimension
    image = tf.expand_dims(image, 0)
    return image

# %%
def train_test_model(hparams, session_num):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(
            hparams[HP_FILTER_NUM], 
            hparams[HP_FILTER_SIZE_1], 
            activation='relu',
            input_shape=(120,90,3)),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Conv2D(
            hparams[HP_FILTER_NUM], 
            hparams[HP_FILTER_SIZE_2], 
            activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(hparams[HP_DENSE_SIZE], activation='relu'),
        tf.keras.layers.Dense(5)
    ])
    
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    model.compile(optimizer="adam", loss=loss_fn, metrics=['accuracy'])
    

    log_dir = "Logs\\Model 5_2\\fit\\" + "run {}".format(session_num)
    
  
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')
    
    def log_confusion_matrix(epoch, logs):
        
        test_pred_raw = model.predict(images_val)
        test_pred = np.argmax(test_pred_raw, axis=1)

        
        cm = sklearn.metrics.confusion_matrix(labels_val, test_pred)
       
        figure = plot_confusion_matrix(cm, class_names=['Boots', "Trainers/Sneakers", "Sandals/Flip flops/Slippers","Formal shoes",
                                                        'Others'])
        cm_image = plot_to_image(figure)

        
        with file_writer_cm.as_default():
            tf.summary.image("Confusion Matrix", cm_image, step=epoch)
    
    
    
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch=0)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)
    

    
 
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor = 'val_loss',
        mode = 'auto',
        min_delta = 0,
        patience = 2,
        verbose = 0, 
        restore_best_weights = True
    )
    

    model.fit(
        images_train,
        labels_train,
        epochs = EPOCHS,
        batch_size = BATCH_SIZE,
        callbacks = [tensorboard_callback, cm_callback, early_stopping],
        validation_data = (images_val,labels_val),
        verbose = 2
    )
    
    

    _, accuracy = model.evaluate(images_val,labels_val)
    

    model.save(r"saved_models\Model 5_2\Run-{}".format(session_num))
    
    return accuracy

# %%
def run(log_dir, hparams, session_num):
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step = 1)

# %%
session_num = 1

for filter_size_1 in HP_FILTER_SIZE_1.domain.values:
    for filter_num in HP_FILTER_NUM.domain.values:
        for filter_size_2 in HP_FILTER_SIZE_2.domain.values:
            for dense_size in HP_DENSE_SIZE.domain.values:

                    hparams = {
                        HP_FILTER_SIZE_1: filter_size_1,
                        HP_FILTER_NUM: filter_num,
                        HP_FILTER_SIZE_2: filter_size_2,
                        HP_DENSE_SIZE: dense_size
                    }

                    run_name = "run-%d" % session_num
                    print('--- Starting trial: %s' % run_name)
                    print({h.name: hparams[h] for h in hparams})
                    run('Logs/Model 5_2/hparam_tuning/' + run_name, hparams, session_num)

                    session_num += 1
# Out:
# --- Starting trial: run-1
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 256}
# Epoch 1/15
# 33/33 - 9s - loss: 1.1006 - accuracy: 0.6059 - val_loss: 0.5261 - val_accuracy: 0.8301
# Epoch 2/15
# 33/33 - 8s - loss: 0.5174 - accuracy: 0.8075 - val_loss: 0.4081 - val_accuracy: 0.8263
# Epoch 3/15
# 33/33 - 8s - loss: 0.4087 - accuracy: 0.8553 - val_loss: 0.4020 - val_accuracy: 0.8456
# Epoch 4/15
# 33/33 - 8s - loss: 0.3533 - accuracy: 0.8726 - val_loss: 0.3470 - val_accuracy: 0.8533
# Epoch 5/15
# 33/33 - 8s - loss: 0.3315 - accuracy: 0.8736 - val_loss: 0.3124 - val_accuracy: 0.8649
# Epoch 6/15
# 33/33 - 8s - loss: 0.2737 - accuracy: 0.9045 - val_loss: 0.3696 - val_accuracy: 0.8649
# Epoch 7/15
# 33/33 - 7s - loss: 0.2460 - accuracy: 0.9108 - val_loss: 0.3132 - val_accuracy: 0.8571
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3124 - accuracy: 0.8649
# INFO:tensorflow:Assets written to: saved_models\Model 5_2\Run-1\assets
# --- Starting trial: run-2
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 33/33 - 10s - loss: 1.7767 - accuracy: 0.5519 - val_loss: 0.6429 - val_accuracy: 0.7683
# Epoch 2/15
# 33/33 - 9s - loss: 0.6224 - accuracy: 0.7665 - val_loss: 0.4780 - val_accuracy: 0.8301
# Epoch 3/15
# 33/33 - 9s - loss: 0.4529 - accuracy: 0.8379 - val_loss: 0.3887 - val_accuracy: 0.8571
# Epoch 4/15
# 33/33 - 9s - loss: 0.3981 - accuracy: 0.8567 - val_loss: 0.3766 - val_accuracy: 0.8533
- accuracy: 0.8803
# INFO:tensorflow:Assets written to: saved_models\Model 5_2\Run-24\assets
# --- Starting trial: run-25
# {'filter_size_1': 7, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 256}
# Epoch 1/15
# 33/33 - 6s - loss: 1.2586 - accuracy: 0.5721 - val_loss: 0.7019 - val_accuracy: 0.7645
# Epoch 2/15
# 33/33 - 6s - loss: 0.6155 - accuracy: 0.7709 - val_loss: 0.4861 - val_accuracy: 0.8147
# Epoch 3/15
# 33/33 - 6s - loss: 0.4740 - accuracy: 0.8205 - val_loss: 0.4169 - val_accuracy: 0.8378
# Epoch 4/15
# 33/33 - 6s - loss: 0.4285 - accuracy: 0.8326 - val_loss: 0.3705 - val_accuracy: 0.8687
# Epoch 5/15
# 33/33 - 6s - loss: 0.3384 - accuracy: 0.8755 - val_loss: 0.3401 - val_accuracy: 0.8571
# Epoch 6/15
# 33/33 - 6s - loss: 0.3545 - accuracy: 0.8683 - val_loss: 0.3852 - val_accuracy: 0.8456
# Epoch 7/15
# 33/33 - 6s - loss: 0.3330 - accuracy: 0.8736 - val_loss: 0.3164 - val_accuracy: 0.8803
# Epoch 8/15
# 33/33 - 6s - loss: 0.2451 - accuracy: 0.9088 - val_loss: 0.3441 - val_accuracy: 0.8803
# Epoch 9/15
# 33/33 - 6s - loss: 0.2466 - accuracy: 0.9040 - val_loss: 0.3000 - val_accuracy: 0.8803
# Epoch 10/15
# 33/33 - 6s - loss: 0.2059 - accuracy: 0.9243 - val_loss: 0.3386 - val_accuracy: 0.8919
# Epoch 11/15
# 33/33 - 6s - loss: 0.2276 - accuracy: 0.9141 - val_loss: 0.3393 - val_accuracy: 0.8649
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3000 - accuracy: 0.8803
# INFO:tensorflow:Assets written to: saved_models\Model 5_2\Run-25\assets
# --- Starting trial: run-26
# {'filter_size_1': 7, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 33/33 - 7s - loss: 1.3133 - accuracy: 0.5692 - val_loss: 0.7363 - val_accuracy: 0.7452
# Epoch 2/15
# 33/33 - 7s - loss: 0.6136 - accuracy: 0.7757 - val_loss: 0.5373 - val_accuracy: 0.7761
# Epoch 3/15
# 33/33 - 7s - loss: 0.5223 - accuracy: 0.8070 - val_loss: 0.4301 - val_accuracy: 0.8378
# Epoch 4/15
# 33/33 - 7s - loss: 0.4390 - accuracy: 0.8418 - val_loss: 0.4596 - val_accuracy: 0.8224
# Epoch 5/15
# 33/33 - 7s - loss: 0.4110 - accuracy: 0.8490 - val_loss: 0.4096 - val_accuracy: 0.8417
# Epoch 6/15
# 33/33 - 7s - loss: 0.3786 - accuracy: 0.8611 - val_loss: 0.3458 - val_accuracy: 0.8571
# Epoch 7/15
# 33/33 - 7s - loss: 0.3156 - accuracy: 0.8876 - val_loss: 0.3255 - val_accuracy: 0.8494
# Epoch 8/15
# 33/33 - 7s - loss: 0.2886 - accuracy: 0.8862 - val_loss: 0.3497 - val_accuracy: 0.8687
# Epoch 9/15
# 33/33 - 7s - loss: 0.2621 - accuracy: 0.8987 - val_loss: 0.3778 - val_accuracy: 0.8571
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3255 - accuracy: 0.8494
# INFO:tensorflow:Assets written to: saved_models\Model 5_2\Run-26\assets
# --- Starting trial: run-27
# {'filter_size_1': 7, 'filters_number': 32, 'filter_size_2': 5, 'dense_size': 256}
# Epoch 1/15
# 33/33 - 9s - loss: 1.2132 - accuracy: 0.5692 - val_loss: 0.5797 - val_accuracy: 0.8147
# Epoch 2/15
# 33/33 - 8s - loss: 0.6075 - accuracy: 0.7805 - val_loss: 0.5568 - val_accuracy: 0.7838
# Epoch 3/15
# 33/33 - 8s - loss: 0.5231 - accuracy: 0.8138 - val_loss: 0.4089 - val_accuracy: 0.8340
# Epoch 4/15
# 33/33 - 8s - loss: 0.4508 - accuracy: 0.8360 - val_loss: 0.4011 - val_accuracy: 0.8340
# Epoch 5/15
# 33/33 - 8s - loss: 0.4265 - accuracy: 0.8509 - val_loss: 0.4774 - val_accuracy: 0.8147
# Epoch 6/15
# 33/33 - 8s - loss: 0.3977 - accuracy: 0.8635 - val_loss: 0.4382 - val_accuracy: 0.8185
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4011 - accuracy: 0.8340
# INFO:tensorflow:Assets written to: saved_models\Model 5_2\Run-27\assets
# --- Starting trial: run-28
# {'filter_size_1': 7, 'filters_number': 32, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 33/33 - 9s - loss: 1.2292 - accuracy: 0.6020 - val_loss: 0.5498 - val_accuracy: 0.7992
# Epoch 2/15
# 33/33 - 9s - loss: 0.5516 - accuracy: 0.7979 - val_loss: 0.5266 - val_accuracy: 0.8069
# Epoch 3/15
# 33/33 - 9s - loss: 0.5024 - accuracy: 0.8148 - val_loss: 0.3892 - val_accuracy: 0.8726
# Epoch 4/15
# 33/33 - 9s - loss: 0.3989 - accuracy: 0.8534 - val_loss: 0.3853 - val_accuracy: 0.8687
# Epoch 5/15
# 33/33 - 9s - loss: 0.3784 - accuracy: 0.8649 - val_loss: 0.3838 - val_accuracy: 0.8649
# Epoch 6/15
# 33/33 - 9s - loss: 0.3541 - accuracy: 0.8722 - val_loss: 0.3674 - val_accuracy: 0.8571
# Epoch 7/15
# 33/33 - 9s - loss: 0.3182 - accuracy: 0.8818 - val_loss: 0.4086 - val_accuracy: 0.8456
# Epoch 8/15
# 33/33 - 9s - loss: 0.2878 - accuracy: 0.8977 - val_loss: 0.3466 - val_accuracy: 0.8764
# Epoch 9/15
# 33/33 - 9s - loss: 0.2334 - accuracy: 0.9185 - val_loss: 0.3407 - val_accuracy: 0.8803
# Epoch 10/15
# 33/33 - 9s - loss: 0.2316 - accuracy: 0.9175 - val_loss: 0.3112 - val_accuracy: 0.8803
# Epoch 11/15
# 33/33 - 9s - loss: 0.2009 - accuracy: 0.9291 - val_loss: 0.3732 - val_accuracy: 0.8803
# Epoch 12/15
# 33/33 - 9s - loss: 0.1804 - accuracy: 0.9383 - val_loss: 0.3499 - val_accuracy: 0.8919
# 9/9 [==============================] - 0s 24ms/step - loss: 0.3112 - accuracy: 0.8803
# INFO:tensorflow:Assets written to: saved_models\Model 5_2\Run-28\assets
# --- Starting trial: run-29
# {'filter_size_1': 7, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 256}
# Epoch 1/15
# 33/33 - 13s - loss: 1.4251 - accuracy: 0.5364 - val_loss: 0.6648 - val_accuracy: 0.7761
# Epoch 2/15
# 33/33 - 13s - loss: 0.6879 - accuracy: 0.7472 - val_loss: 0.5805 - val_accuracy: 0.7915
# Epoch 3/15
# 33/33 - 13s - loss: 0.5213 - accuracy: 0.8095 - val_loss: 0.5850 - val_accuracy: 0.7915
# Epoch 4/15
# 33/33 - 13s - loss: 0.4805 - accuracy: 0.8205 - val_loss: 0.3927 - val_accuracy: 0.8571
# Epoch 5/15
# 33/33 - 13s - loss: 0.4158 - accuracy: 0.8505 - val_loss: 0.3811 - val_accuracy: 0.8687
# Epoch 6/15
# 33/33 - 13s - loss: 0.3587 - accuracy: 0.8688 - val_loss: 0.4132 - val_accuracy: 0.8456
# Epoch 7/15
# 33/33 - 13s - loss: 0.3541 - accuracy: 0.8659 - val_loss: 0.3506 - val_accuracy: 0.8803
# Epoch 8/15
# 33/33 - 13s - loss: 0.3148 - accuracy: 0.8746 - val_loss: 0.3662 - val_accuracy: 0.8803
# Epoch 9/15
# 33/33 - 13s - loss: 0.2786 - accuracy: 0.8919 - val_loss: 0.3591 - val_accuracy: 0.8610
# 9/9 [==============================] - 0s 37ms/step - loss: 0.3506 - accuracy: 0.8803
# INFO:tensorflow:Assets written to: saved_models\Model 5_2\Run-29\assets
# --- Starting trial: run-30
# {'filter_size_1': 7, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 33/33 - 15s - loss: 1.5865 - accuracy: 0.5094 - val_loss: 0.7190 - val_accuracy: 0.7915
# Epoch 2/15
# 33/33 - 14s - loss: 0.6269 - accuracy: 0.7795 - val_loss: 0.4754 - val_accuracy: 0.8263
# Epoch 3/15
# 33/33 - 14s - loss: 0.5095 - accuracy: 0.8186 - val_loss: 0.5122 - val_accuracy: 0.8108
# Epoch 4/15
# 33/33 - 14s - loss: 0.5233 - accuracy: 0.8099 - val_loss: 0.4238 - val_accuracy: 0.8301
# Epoch 5/15
# 33/33 - 14s - loss: 0.4135 - accuracy: 0.8524 - val_loss: 0.3940 - val_accuracy: 0.8494
# Epoch 6/15
# 33/33 - 14s - loss: 0.3848 - accuracy: 0.8596 - val_loss: 0.3956 - val_accuracy: 0.8571
# Epoch 7/15
# 33/33 - 14s - loss: 0.3415 - accuracy: 0.8808 - val_loss: 0.4231 - val_accuracy: 0.8687
# 9/9 [==============================] - 0s 41ms/step - loss: 0.3940 - accuracy: 0.8494
# INFO:tensorflow:Assets written to: saved_models\Model 5_2\Run-30\assets
# --- Starting trial: run-31
# {'filter_size_1': 7, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 256}
# Epoch 1/15
# 33/33 - 19s - loss: 1.5030 - accuracy: 0.4689 - val_loss: 0.7535 - val_accuracy: 0.7297
# Epoch 2/15
# 33/33 - 18s - loss: 0.6739 - accuracy: 0.7622 - val_loss: 0.4968 - val_accuracy: 0.8301
# Epoch 3/15
# 33/33 - 18s - loss: 0.5666 - accuracy: 0.7863 - val_loss: 0.4680 - val_accuracy: 0.8224
# Epoch 4/15
# 33/33 - 18s - loss: 0.4602 - accuracy: 0.8321 - val_loss: 0.4380 - val_accuracy: 0.8417
# Epoch 5/15
# 33/33 - 18s - loss: 0.4096 - accuracy: 0.8423 - val_loss: 0.3911 - val_accuracy: 0.8417
# Epoch 6/15
# 33/33 - 18s - loss: 0.3536 - accuracy: 0.8693 - val_loss: 0.4072 - val_accuracy: 0.8263
# Epoch 7/15
# 33/33 - 18s - loss: 0.3371 - accuracy: 0.8712 - val_loss: 0.3400 - val_accuracy: 0.8803
# Epoch 8/15
# 33/33 - 18s - loss: 0.3314 - accuracy: 0.8780 - val_loss: 0.5948 - val_accuracy: 0.8069
# Epoch 9/15
# 33/33 - 18s - loss: 0.3062 - accuracy: 0.8780 - val_loss: 0.4242 - val_accuracy: 0.8494
# 9/9 [==============================] - 0s 46ms/step - loss: 0.3400 - accuracy: 0.8803
# INFO:tensorflow:Assets written to: saved_models\Model 5_2\Run-31\assets
# --- Starting trial: run-32
# {'filter_size_1': 7, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 33/33 -
# {'filter_size_1': 7, 'filters_number': 96, 'filter_size_2': 5, 'dense_size': 256}
# Epoch 1/15
# 33/33 - 29s - loss: 1.7835 - accuracy: 0.4781 - val_loss: 0.7217 - val_accuracy: 0.7452
# Epoch 2/15
# 33/33 - 29s - loss: 0.6986 - accuracy: 0.7453 - val_loss: 0.5491 - val_accuracy: 0.8108
# Epoch 3/15
# 33/33 - 28s - loss: 0.5651 - accuracy: 0.7955 - val_loss: 0.4993 - val_accuracy: 0.8185
# Epoch 4/15
# 33/33 - 28s - loss: 0.5552 - accuracy: 0.8075 - val_loss: 0.4747 - val_accuracy: 0.8108
# Epoch 5/15
# 33/33 - 29s - loss: 0.4622 - accuracy: 0.8205 - val_loss: 0.3822 - val_accuracy: 0.8494
# Epoch 6/15
# 33/33 - 29s - loss: 0.4023 - accuracy: 0.8529 - val_loss: 0.3804 - val_accuracy: 0.8649
# Epoch 7/15
# 33/33 - 29s - loss: 0.3896 - accuracy: 0.8582 - val_loss: 0.4023 - val_accuracy: 0.8378
# Epoch 8/15
# 33/33 - 29s - loss: 0.3588 - accuracy: 0.8649 - val_loss: 0.3705 - val_accuracy: 0.8764
# Epoch 9/15
# 33/33 - 29s - loss: 0.3048 - accuracy: 0.8886 - val_loss: 0.3413 - val_accuracy: 0.8842
# Epoch 10/15
# 33/33 - 29s - loss: 0.2750 - accuracy: 0.9011 - val_loss: 0.3333 - val_accuracy: 0.8880
# Epoch 11/15
# 33/33 - 29s - loss: 0.2593 - accuracy: 0.9040 - val_loss: 0.3607 - val_accuracy: 0.8842
# Epoch 12/15
# 33/33 - 29s - loss: 0.2012 - accuracy: 0.9243 - val_loss: 0.3531 - val_accuracy: 0.8803
# 9/9 [==============================] - 1s 78ms/step - loss: 0.3333 - accuracy: 0.8880
# INFO:tensorflow:Assets written to: saved_models\Model 5_2\Run-35\assets
# --- Starting trial: run-36
# {'filter_size_1': 7, 'filters_number': 96, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 33/33 - 30s - loss: 1.7841 - accuracy: 0.4737 - val_loss: 0.6778 - val_accuracy: 0.7722
# Epoch 2/15
# 33/33 - 30s - loss: 0.7138 - accuracy: 0.7521 - val_loss: 0.5371 - val_accuracy: 0.8263
# Epoch 3/15
# 33/33 - 30s - loss: 0.5914 - accuracy: 0.7853 - val_loss: 0.4796 - val_accuracy: 0.8031
# Epoch 4/15
# 33/33 - 30s - loss: 0.4997 - accuracy: 0.8205 - val_loss: 0.4223 - val_accuracy: 0.8378
# Epoch 5/15
# 33/33 - 30s - loss: 0.4589 - accuracy: 0.8288 - val_loss: 0.4452 - val_accuracy: 0.8378
# Epoch 6/15
# 33/33 - 30s - loss: 0.4157 - accuracy: 0.8408 - val_loss: 0.3999 - val_accuracy: 0.8610
# Epoch 7/15
# 33/33 - 31s - loss: 0.3864 - accuracy: 0.8582 - val_loss: 0.4114 - val_accuracy: 0.8571
# Epoch 8/15
# 33/33 - 30s - loss: 0.3815 - accuracy: 0.8630 - val_loss: 0.4118 - val_accuracy: 0.8533
# 9/9 [==============================] - 1s 82ms/step - loss: 0.3999 - accuracy: 0.8610
# INFO:tensorflow:Assets written to: saved_models\Model 5_2\Run-36\assets

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 5_2/hparam_tuning"
# Out:
#       <iframe id="tensorboard-frame-7f6c411ebd42a6c3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7f6c411ebd42a6c3");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
