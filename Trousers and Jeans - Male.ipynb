# %% [markdown]
# # Trousers and jeans model

# %% [markdown]
# # Import relevant libraries

# %%
import io
import itertools
import numpy as np
import sklearn.metrics
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the data

# %%
data_train = np.load(r"data/Trousers & Jeans - Male - Train.npz")
data_validation = np.load(r"data/Trousers & Jeans - Male - Validation.npz")
data_test = np.load(r"data/Trousers & Jeans - Male - Test.npz")

print("Data train files: {}".format(data_train.files))
print("Size of the images: {}".format(data_train['images'].shape))
print("Size of the labels: {}".format(data_train['labels'].shape))
print("Unique values of the labels: {}".format(np.unique(data_train['labels'])))
n = np.random.randint(0, 2002)
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(data_train['images'][n])
print("The label of {}'th image is {}".format(n, data_train['labels'][n]))

n = np.random.randint(0, 2002)
ax2.imshow(data_train['images'][n])
print("The label of {}'th image is {}".format(n, data_train['labels'][n]))
# Out:
# Data train files: ['images', 'labels']
# Size of the images: (2002, 120, 90, 3)
# Size of the labels: (2002,)
# Unique values of the labels: [0 1]
# The label of 873'th image is 0
# The label of 1344'th image is 0

# %%
images_train = data_train['images']
labels_train = data_train['labels']

images_val = data_validation['images']
labels_val = data_validation['labels']

images_test = data_test['images']
labels_test = data_test['labels']

# %%
images_train = images_train/255.0
images_val = images_val/255.0
images_test = images_test/255.0

# %% [markdown]
# # Training the models

# %%
EPOCHS = 15
BATCH_SIZE = 64 #power of 2

HP_FILTER_SIZE_1 = hp.HParam('filter_size_1', hp.Discrete([3,5,7]))
HP_FILTER_NUM = hp.HParam('filters_number', hp.Discrete([32,64]))
HP_FILTER_SIZE_2 = hp.HParam('filter_size_2', hp.Discrete([3,5]))
HP_DENSE_SIZE = hp.HParam('dense_size', hp.Discrete([256,512]))

METRIC_ACCURACY = "accuracy"

with tf.summary.create_file_writer(r'Logs/Model 4_2/hparam_tuning/').as_default():
    hp.hparams_config(
        hparams=[HP_FILTER_SIZE_1, HP_FILTER_NUM, HP_FILTER_SIZE_2, HP_DENSE_SIZE],
        metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
    )

# %%
def plot_confusion_matrix(cm, class_names):
    """
    Returns a matplotlib figure containing the plotted confusion matrix.

    Args:
        cm (array, shape = [n, n]): a confusion matrix of integer classes
        class_names (array, shape = [n]): String names of the integer classes
    """
    figure = plt.figure(figsize=(12, 12))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    # Normalize the confusion matrix.
    cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return figure

# %%
def plot_to_image(figure):
    """Converts the matplotlib plot specified by 'figure' to a PNG image and
    returns it. The supplied figure is closed and inaccessible after this call."""
    # Save the plot to a PNG in memory.
    buf = io.BytesIO()
    plt.savefig(buf, format='png')
    # Closing the figure prevents it from being displayed directly inside
    # the notebook.
    plt.close(figure)
    buf.seek(0)
    # Convert PNG buffer to TF image
    image = tf.image.decode_png(buf.getvalue(), channels=4)
    # Add the batch dimension
    image = tf.expand_dims(image, 0)
    return image

# %%
def train_test_model(hparams, session_num):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(
            hparams[HP_FILTER_NUM], 
            hparams[HP_FILTER_SIZE_1], 
            activation='relu',
            input_shape=(120,90,3)),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Conv2D(
            hparams[HP_FILTER_NUM], 
            hparams[HP_FILTER_SIZE_2], 
            activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(hparams[HP_DENSE_SIZE], activation='relu'),
        tf.keras.layers.Dense(2)
    ])
    
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    model.compile(optimizer="adam", loss=loss_fn, metrics=['accuracy'])
    

    log_dir = "Logs\\Model 4_2\\fit\\" + "run {}".format(session_num)
    
  
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')
    
    def log_confusion_matrix(epoch, logs):
        
        test_pred_raw = model.predict(images_val)
        test_pred = np.argmax(test_pred_raw, axis=1)

        
        cm = sklearn.metrics.confusion_matrix(labels_val, test_pred)
       
        figure = plot_confusion_matrix(cm, class_names=['Trousers', 'Jeans'])
        cm_image = plot_to_image(figure)

        
        with file_writer_cm.as_default():
            tf.summary.image("Confusion Matrix", cm_image, step=epoch)
    
    
    
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch=0)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)
    

    
 
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor = 'val_loss',
        mode = 'auto',
        min_delta = 0,
        patience = 2,
        verbose = 0, 
        restore_best_weights = True
    )
    

    model.fit(
        images_train,
        labels_train,
        epochs = EPOCHS,
        batch_size = BATCH_SIZE,
        callbacks = [tensorboard_callback, cm_callback, early_stopping],
        validation_data = (images_val,labels_val),
        verbose = 2
    )
    
    

    _, accuracy = model.evaluate(images_val,labels_val)
    

    model.save(r"saved_models\Model 4_2\Run-{}".format(session_num))
    
    return accuracy

# %%
def run(log_dir, hparams, session_num):
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step = 1)

# %%
session_num = 1

for filter_size_1 in HP_FILTER_SIZE_1.domain.values:
    for filter_num in HP_FILTER_NUM.domain.values:
        for filter_size_2 in HP_FILTER_SIZE_2.domain.values:
            for dense_size in HP_DENSE_SIZE.domain.values:

                    hparams = {
                        HP_FILTER_SIZE_1: filter_size_1,
                        HP_FILTER_NUM: filter_num,
                        HP_FILTER_SIZE_2: filter_size_2,
                        HP_DENSE_SIZE: dense_size
                    }

                    run_name = "run-%d" % session_num
                    print('--- Starting trial: %s' % run_name)
                    print({h.name: hparams[h] for h in hparams})
                    run('Logs/Model 4_2/hparam_tuning/' + run_name, hparams, session_num)

                    session_num += 1
# Out:
# --- Starting trial: run-1
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 5s - loss: 0.9504 - accuracy: 0.6334 - val_loss: 0.5120 - val_accuracy: 0.7480
# Epoch 2/15
# 32/32 - 5s - loss: 0.4635 - accuracy: 0.7832 - val_loss: 0.4328 - val_accuracy: 0.7880
# Epoch 3/15
# 32/32 - 5s - loss: 0.4100 - accuracy: 0.8202 - val_loss: 0.4216 - val_accuracy: 0.8200
# Epoch 4/15
# 32/32 - 5s - loss: 0.3558 - accuracy: 0.8432 - val_loss: 0.3801 - val_accuracy: 0.8120
# Epoch 5/15
# 32/32 - 5s - loss: 0.3531 - accuracy: 0.8392 - val_loss: 0.3439 - val_accuracy: 0.8440
# Epoch 6/15
# 32/32 - 5s - loss: 0.2998 - accuracy: 0.8681 - val_loss: 0.3145 - val_accuracy: 0.8600
# Epoch 7/15
# 32/32 - 5s - loss: 0.2677 - accuracy: 0.8776 - val_loss: 0.3674 - val_accuracy: 0.8480
# Epoch 8/15
# 32/32 - 8s - loss: 0.2817 - accuracy: 0.8751 - val_loss: 0.3309 - val_accuracy: 0.8520
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3145 - accuracy: 0.8600
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-1\assets
# --- Starting trial: run-2
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 10s - loss: 0.9288 - accuracy: 0.6409 - val_loss: 0.5575 - val_accuracy: 0.7120
# Epoch 2/15
# 32/32 - 8s - loss: 0.4545 - accuracy: 0.7942 - val_loss: 0.4052 - val_accuracy: 0.8200
# Epoch 3/15
# 32/32 - 9s - loss: 0.4171 - accuracy: 0.8072 - val_loss: 0.4005 - val_accuracy: 0.8160
# Epoch 4/15
# 32/32 - 9s - loss: 0.3583 - accuracy: 0.8327 - val_loss: 0.3510 - val_accuracy: 0.8320
# Epoch 5/15
# 32/32 - 8s - loss: 0.3246 - accuracy: 0.8616 - val_loss: 0.3129 - val_accuracy: 0.8560
# Epoch 6/15
# 32/32 - 8s - loss: 0.2784 - accuracy: 0.8766 - val_loss: 0.2903 - val_accuracy: 0.8800
# Epoch 7/15
# 32/32 - 9s - loss: 0.2479 - accuracy: 0.8976 - val_loss: 0.3070 - val_accuracy: 0.8680
# Epoch 8/15
# 32/32 - 9s - loss: 0.2476 - accuracy: 0.9031 - val_loss: 0.2817 - val_accuracy: 0.8720
# Epoch 9/15
# 32/32 - 8s - loss: 0.2343 - accuracy: 0.9041 - val_loss: 0.5005 - val_accuracy: 0.7760
# Epoch 10/15
# 32/32 - 8s - loss: 0.2483 - accuracy: 0.8841 - val_loss: 0.3533 - val_accuracy: 0.8400
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2817 - accuracy: 0.8720
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-2\assets
# --- Starting trial: run-3
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 5, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 12s - loss: 0.8249 - accuracy: 0.6419 - val_loss: 0.5582 - val_accuracy: 0.7200
# Epoch 2/15
# 32/32 - 12s - loss: 0.4995 - accuracy: 0.7647 - val_loss: 0.4570 - val_accuracy: 0.7800
# Epoch 3/15
# 32/32 - 13s - loss: 0.4539 - accuracy: 0.7952 - val_loss: 0.4734 - val_accuracy: 0.7760
# Epoch 4/15
# 32/32 - 13s - loss: 0.4273 - accuracy: 0.8037 - val_loss: 0.4004 - val_accuracy: 0.7920
# Epoch 5/15
# 32/32 - 13s - loss: 0.4106 - accuracy: 0.8177 - val_loss: 0.3691 - val_accuracy: 0.8160
# Epoch 6/15
# 32/32 - 12s - loss: 0.3819 - accuracy: 0.8202 - val_loss: 0.3624 - val_accuracy: 0.8160
# Epoch 7/15
# 32/32 - 13s - loss: 0.3512 - accuracy: 0.8392 - val_loss: 0.3619 - val_accuracy: 0.8240
# Epoch 8/15
# 32/32 - 13s - loss: 0.3323 - accuracy: 0.8611 - val_loss: 0.3173 - val_accuracy: 0.8520
# Epoch 9/15
# 32/32 - 13s - loss: 0.3017 - accuracy: 0.8716 - val_loss: 0.3229 - val_accuracy: 0.8640
# Epoch 10/15
# 32/32 - 13s - loss: 0.2923 - accuracy: 0.8776 - val_loss: 0.3521 - val_accuracy: 0.8440
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3173 - accuracy: 0.8520
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-3\assets
# --- Starting trial: run-4
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 13s - loss: 0.8120 - accuracy: 0.6583 - val_loss: 0.6778 - val_accuracy: 0.5840
# Epoch 2/15
# 32/32 - 14s - loss: 0.5084 - accuracy: 0.7642 - val_loss: 0.5193 - val_accuracy: 0.7760
# Epoch 3/15
# 32/32 - 14s - loss: 0.4862 - accuracy: 0.7762 - val_loss: 0.4995 - val_accuracy: 0.7480
# Epoch 4/15
# 32/32 - 14s - loss: 0.4206 - accuracy: 0.8067 - val_loss: 0.3751 - val_accuracy: 0.8080
# Epoch 5/15
# 32/32 - 14s - loss: 0.3657 - accuracy: 0.8352 - val_loss: 0.3573 - val_accuracy: 0.8400
# Epoch 6/15
# 32/32 - 14s - loss: 0.3197 - accuracy: 0.8556 - val_loss: 0.3318 - val_accuracy: 0.8440
# Epoch 7/15
# 32/32 - 14s - loss: 0.3050 - accuracy: 0.8666 - val_loss: 0.3308 - val_accuracy: 0.8680
# Epoch 8/15
# 32/32 - 13s - loss: 0.2729 - accuracy: 0.8741 - val_loss: 0.2869 - val_accuracy: 0.8880
# Epoch 9/15
# 32/32 - 13s - loss: 0.2511 - accuracy: 0.8981 - val_loss: 0.3258 - val_accuracy: 0.8640
# Epoch 10/15
# 32/32 - 11s - loss: 0.2401 - accuracy: 0.8986 - val_loss: 0.2755 - val_accuracy: 0.8920
# Epoch 11/15
# 32/32 - 13s - loss: 0.2504 - accuracy: 0.8891 - val_loss: 0.3168 - val_accuracy: 0.8800
# Epoch 12/15
# 32/32 - 14s - loss: 0.2078 - accuracy: 0.9041 - val_loss: 0.2960 - val_accuracy: 0.9080
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2755 - accuracy: 0.8920
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-4\assets
# --- Starting trial: run-5
# {'filter_size_1': 3, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 19s - loss: 0.6948 - accuracy: 0.6533 - val_loss: 0.6443 - val_accuracy: 0.6840
# Epoch 2/15
# 32/32 - 18s - loss: 0.5013 - accuracy: 0.7642 - val_loss: 0.4469 - val_accuracy: 0.7960
# Epoch 3/15
# 32/32 - 17s - loss: 0.4214 - accuracy: 0.7987 - val_loss: 0.3833 - val_accuracy: 0.8280
# Epoch 4/15
# 32/32 - 17s - loss: 0.3913 - accuracy: 0.8277 - val_loss: 0.3962 - val_accuracy: 0.8320
# Epoch 5/15
# 32/32 - 17s - loss: 0.3393 - accuracy: 0.8482 - val_loss: 0.3792 - val_accuracy: 0.8240
# Epoch 6/15
# 32/32 - 15s - loss: 0.2879 - accuracy: 0.8686 - val_loss: 0.3164 - val_accuracy: 0.8680
# Epoch 7/15
# 32/32 - 18s - loss: 0.2776 - accuracy: 0.8766 - val_loss: 0.3467 - val_accuracy: 0.8480
# Epoch 8/15
# 32/32 - 18s - loss: 0.2733 - accuracy: 0.8851 - val_loss: 0.3098 - val_accuracy: 0.8640
# Epoch 9/15
# 32/32 - 17s - loss: 0.2643 - accuracy: 0.8836 - val_loss: 0.3093 - val_accuracy: 0.8720
# Epoch 10/15
# 32/32 - 17s - loss: 0.2300 - accuracy: 0.8966 - val_loss: 0.3319 - val_accuracy: 0.8680
# Epoch 11/15
# 32/32 - 17s - loss: 0.2271 - accuracy: 0.9021 - val_loss: 0.3272 - val_accuracy: 0.8640
# 8/8 [==============================] - 1s 59ms/step - loss: 0.3093 - accuracy: 0.8720
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-5\assets
# --- Starting trial: run-6
# {'filter_size_1': 3, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 19s - loss: 1.0443 - accuracy: 0.6489 - val_loss: 0.5591 - val_accuracy: 0.7320
# Epoch 2/15
# 32/32 - 18s - loss: 0.4839 - accuracy: 0.7757 - val_loss: 0.4845 - val_accuracy: 0.7800
# Epoch 3/15
# 32/32 - 18s - loss: 0.4095 - accuracy: 0.8122 - val_loss: 0.4000 - val_accuracy: 0.8240
# Epoch 4/15
# 32/32 - 18s - loss: 0.3737 - accuracy: 0.8282 - val_loss: 0.3924 - val_accuracy: 0.8120
# Epoch 5/15
# 32/32 - 18s - loss: 0.3511 - accuracy: 0.8427 - val_loss: 0.3495 - val_accuracy: 0.8280
# Epoch 6/15
# 32/32 - 15s - loss: 0.3066 - accuracy: 0.8566 - val_loss: 0.3123 - val_accuracy: 0.8520
# Epoch 7/15
# 32/32 - 19s - loss: 0.2846 - accuracy: 0.8641 - val_loss: 0.3588 - val_accuracy: 0.8240
# Epoch 8/15
# 32/32 - 22s - loss: 0.2552 - accuracy: 0.8881 - val_loss: 0.3064 - val_accuracy: 0.8520
# Epoch 9/15
# 32/32 - 20s - loss: 0.2513 - accuracy: 0.8891 - val_loss: 0.3213 - val_accuracy: 0.8480
# Epoch 10/15
# 32/32 - 19s - loss: 0.2793 - accuracy: 0.8756 - val_loss: 0.4333 - val_accuracy: 0.8040
# 8/8 [==============================] - 1s 76ms/step - loss: 0.3064 - accuracy: 0.8520
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-6\assets
# --- Starting trial: run-7
# {'filter_size_1': 3, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 30s - loss: 0.8244 - accuracy: 0.6324 - val_loss: 0.5104 - val_accuracy: 0.7800
# Epoch 2/15
# 32/32 - 30s - loss: 0.5106 - accuracy: 0.7672 - val_loss: 0.4986 - val_accuracy: 0.7640
# Epoch 3/15
# 32/32 - 28s - loss: 0.4423 - accuracy: 0.7907 - val_loss: 0.4523 - val_accuracy: 0.8120
# Epoch 4/15
# 32/32 - 29s - loss: 0.4099 - accuracy: 0.8172 - val_loss: 0.4313 - val_accuracy: 0.7880
# Epoch 5/15
# 32/32 - 29s - loss: 0.3763 - accuracy: 0.8327 - val_loss: 0.3576 - val_accuracy: 0.8440
# Epoch 6/15
# 32/32 - 29s - loss: 0.3360 - accuracy: 0.8452 - val_loss: 0.3485 - val_accuracy: 0.8600
# Epoch 7/15
# 32/32 - 29s - loss: 0.3175 - accuracy: 0.8472 - val_loss: 0.3304 - val_accuracy: 0.8600
# Epoch 8/15
# 32/32 - 28s - loss: 0.2950 - accuracy: 0.8671 - val_loss: 0.4129 - val_accuracy: 0.8080
# Epoch 9/15
# 32/32 - 31s - loss: 0.2945 - accuracy: 0.8606 - val_loss: 0.5107 - val_accuracy: 0.8240
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3304 - accuracy: 0.8600
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-7\assets
# --- Starting trial: run-8
# {'filter_size_1': 3, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 33s - loss: 1.2900 - accuracy: 0.6474 - val_loss: 0.4896 - val_accuracy: 0.7720
# Epoch 2/15
# 32/32 - 33s - loss: 0.4712 - accuracy: 0.7802 - val_loss: 0.4711 - val_accuracy: 0.7960
# Epoch 3/15
# 32/32 - 32s - loss: 0.4089 - accuracy: 0.8237 - val_loss: 0.3606 - val_accuracy: 0.8400
# Epoch 4/15
# 32/32 - 30s - loss: 0.3379 - accuracy: 0.8442 - val_loss: 0.3521 - val_accuracy: 0.8320
# Epoch 5/15
# 32/32 - 30s - loss: 0.3179 - accuracy: 0.8556 - val_loss: 0.3444 - val_accuracy: 0.8280
# Epoch 6/15
# 32/32 - 30s - loss: 0.3615 - accuracy: 0.8347 - val_loss: 0.3627 - val_accuracy: 0.8360
# Epoch 7/15
# 32/32 - 31s - loss: 0.3059 - accuracy: 0.8621 - val_loss: 0.4455 - val_accuracy: 0.7960
# 8/8 [==============================] - 1s 106ms/step - loss: 0.3444 - accuracy: 0.8280
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-8\assets
# --- Starting trial: run-9
# {'filter_size_1': 5, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 10s - loss: 0.7009 - accuracy: 0.6558 - val_loss: 0.5526 - val_accuracy: 0.7560
# Epoch 2/15
# 32/32 - 10s - loss: 0.4909 - accuracy: 0.7692 - val_loss: 0.4422 - val_accuracy: 0.7800
# Epoch 3/15
# 32/32 - 10s - loss: 0.4073 - accuracy: 0.8117 - val_loss: 0.3783 - val_accuracy: 0.8400
# Epoch 4/15
# 32/32 - 9s - loss: 0.3799 - accuracy: 0.8187 - val_loss: 0.4040 - val_accuracy: 0.8120
# Epoch 5/15
# 32/32 - 10s - loss: 0.3647 - accuracy: 0.8327 - val_loss: 0.3923 - val_accuracy: 0.8160
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3783 - accuracy: 0.8400
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-9\assets
# --- Starting trial: run-10
# {'filter_size_1': 5, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 10s - loss: 0.9201 - accuracy: 0.6469 - val_loss: 0.6024 - val_accuracy: 0.6800
# Epoch 2/15
# 32/32 - 10s - loss: 0.4640 - accuracy: 0.7752 - val_loss: 0.4435 - val_accuracy: 0.7880
# Epoch 3/15
# 32/32 - 10s - loss: 0.3925 - accuracy: 0.8237 - val_loss: 0.3901 - val_accuracy: 0.7920
# Epoch 4/15
# 32/32 - 7s - loss: 0.3709 - accuracy: 0.8232 - val_loss: 0.4571 - val_accuracy: 0.7840
# Epoch 5/15
# 32/32 - 10s - loss: 0.3412 - accuracy: 0.8472 - val_loss: 0.4052 - val_accuracy: 0.8080
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3901 - accuracy: 0.7920
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-10\assets
# --- Starting trial: run-11
# {'filter_size_1': 5, 'filters_number': 32, 'filter_size_2': 5, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 16s - loss: 0.7725 - accuracy: 0.6548 - val_loss: 0.6340 - val_accuracy: 0.7200
# Epoch 2/15
# 32/32 - 15s - loss: 0.4581 - accuracy: 0.7882 - val_loss: 0.3976 - val_accuracy: 0.8000
# Epoch 3/15
# 32/32 - 14s - loss: 0.3858 - accuracy: 0.8217 - val_loss: 0.3642 - val_accuracy: 0.8240
# Epoch 4/15
# 32/32 - 15s - loss: 0.3833 - accuracy: 0.8222 - val_loss: 0.3715 - val_accuracy: 0.8400
# Epoch 5/15
# 32/32 - 12s - loss: 0.3518 - accuracy: 0.8412 - val_loss: 0.3504 - val_accuracy: 0.8400
# Epoch 6/15
# 32/32 - 14s - loss: 0.4110 - accuracy: 0.8242 - val_loss: 0.4015 - val_accuracy: 0.8440
# Epoch 7/15
# 32/32 - 15s - loss: 0.3453 - accuracy: 0.8467 - val_loss: 0.3640 - val_accuracy: 0.8440
# 8/8 [==============================] - 0s 56ms/step - loss: 0.3504 - accuracy: 0.8400
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-11\assets
# --- Starting trial: run-12
# {'filter_size_1': 5, 'filters_number': 32, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 17s - loss: 0.9992 - accuracy: 0.6723 - val_loss: 0.4842 - val_accuracy: 0.7840
# Epoch 2/15
# 32/32 - 16s - loss: 0.4915 - accuracy: 0.7767 - val_loss: 0.6319 - val_accuracy: 0.7120
# Epoch 3/15
# 32/32 - 17s - loss: 0.4890 - accuracy: 0.7547 - val_loss: 0.4570 - val_accuracy: 0.7840
# Epoch 4/15
# 32/32 - 14s - loss: 0.3963 - accuracy: 0.8182 - val_loss: 0.4785 - val_accuracy: 0.7520
# Epoch 5/15
# 32/32 - 15s - loss: 0.4233 - accuracy: 0.8032 - val_loss: 0.4885 - val_accuracy: 0.7880
# 8/8 [==============================] - 0s 42ms/step - loss: 0.4570 - accuracy: 0.7840
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-12\assets
# --- Starting trial: run-13
# {'filter_size_1': 5, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 18s - loss: 0.8961 - accuracy: 0.6459 - val_loss: 0.5725 - val_accuracy: 0.7000
# Epoch 2/15
# 32/32 - 18s - loss: 0.4969 - accuracy: 0.7692 - val_loss: 0.4631 - val_accuracy: 0.7720
# Epoch 3/15
# 32/32 - 18s - loss: 0.4456 - accuracy: 0.7997 - val_loss: 0.4117 - val_accuracy: 0.8120
# Epoch 4/15
# 32/32 - 16s - loss: 0.3871 - accuracy: 0.8162 - val_loss: 0.4187 - val_accuracy: 0.8000
# Epoch 5/15
# 32/32 - 18s - loss: 0.3908 - accuracy: 0.8202 - val_loss: 0.4062 - val_accuracy: 0.8120
# Epoch 6/15
# 32/32 - 18s - loss: 0.3520 - accuracy: 0.8412 - val_loss: 0.3785 - val_accuracy: 0.8360
# Epoch 7/15
# 32/32 - 18s - loss: 0.3413 - accuracy: 0.8402 - val_loss: 0.4163 - val_accuracy: 0.8240
# Epoch 8/15
# 32/32 - 19s - loss: 0.3203 - accuracy: 0.8521 - val_loss: 0.3399 - val_accuracy: 0.8400
# Epoch 9/15
# 32/32 - 19s - loss: 0.2856 - accuracy: 0.8656 - val_loss: 0.3385 - val_accuracy: 0.8320
# Epoch 10/15
# 32/32 - 17s - loss: 0.2703 - accuracy: 0.8771 - val_loss: 0.3463 - val_accuracy: 0.8280
# Epoch 11/15
# 32/32 - 18s - loss: 0.2655 - accuracy: 0.8691 - val_loss: 0.3795 - val_accuracy: 0.8320
# 8/8 [==============================] - 0s 55ms/step - loss: 0.3385 - accuracy: 0.8320
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-13\assets
# --- Starting trial: run-14
# {'filter_size_1': 5, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 20s - loss: 0.9920 - accuracy: 0.6224 - val_loss: 0.7523 - val_accuracy: 0.5760
# Epoch 2/15
# 32/32 - 18s - loss: 0.5052 - accuracy: 0.7468 - val_loss: 0.4414 - val_accuracy: 0.7760
# Epoch 3/15
# 32/32 - 20s - loss: 0.4412 - accuracy: 0.7957 - val_loss: 0.5050 - val_accuracy: 0.7720
# Epoch 4/15
# 32/32 - 20s - loss: 0.4054 - accuracy: 0.8172 - val_loss: 0.3921 - val_accuracy: 0.8360
# Epoch 5/15
# 32/32 - 20s - loss: 0.3901 - accuracy: 0.8237 - val_loss: 0.3885 - val_accuracy: 0.8200
# Epoch 6/15
# 32/32 - 21s - loss: 0.3718 - accuracy: 0.8272 - val_loss: 0.5129 - val_accuracy: 0.7840
# Epoch 7/15
# 32/32 - 21s - loss: 0.3770 - accuracy: 0.8307 - val_loss: 0.3845 - val_accuracy: 0.8080
# Epoch 8/15
# 32/32 - 21s - loss: 0.3363 - accuracy: 0.8422 - val_loss: 0.3742 - val_accuracy: 0.8440
# Epoch 9/15
# 32/32 - 22s - loss: 0.3836 - accuracy: 0.8212 - val_loss: 0.3723 - val_accuracy: 0.8040
# Epoch 10/15
# 32/32 - 18s - loss: 0.3106 - accuracy: 0.8621 - val_loss: 0.3439 - val_accuracy: 0.8360
# Epoch 11/15
# 32/32 - 21s - loss: 0.2777 - accuracy: 0.8721 - val_loss: 0.3291 - val_accuracy: 0.8360
# Epoch 12/15
# 32/32 - 22s - loss: 0.5232 - accuracy: 0.8487 - val_loss: 0.3864 - val_accuracy: 0.8240
# Epoch 13/15
# 32/32 - 21s - loss: 0.3467 - accuracy: 0.8422 - val_loss: 0.4143 - val_accuracy: 0.8200
# 8/8 [==============================] - 1s 80ms/step - loss: 0.3291 - accuracy: 0.8360 0s - loss: 0.3359 - accuracy: 0.
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-14\assets
# --- Starting trial: run-15
# {'filter_size_1': 5, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 28s - loss: 0.9629 - accuracy: 0.6034 - val_loss: 0.6407 - val_accuracy: 0.5960
# Epoch 2/15
# 32/32 - 29s - loss: 0.5580 - accuracy: 0.7388 - val_loss: 0.4900 - val_accuracy: 0.7640
# Epoch 3/15
# 32/32 - 29s - loss: 0.4495 - accuracy: 0.7922 - val_loss: 0.4588 - val_accuracy: 0.7760
# Epoch 4/15
# 32/32 - 28s - loss: 0.4539 - accuracy: 0.7917 - val_loss: 0.5180 - val_accuracy: 0.7320
# Epoch 5/15
# 32/32 - 27s - loss: 0.4586 - accuracy: 0.7772 - val_loss: 0.5012 - val_accuracy: 0.7400
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4588 - accuracy: 0.7760
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-15\assets
# --- Starting trial: run-16
# {'filter_size_1': 5, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 32s - loss: 1.0370 - accuracy: 0.6189 - val_loss: 0.5097 - val_accuracy: 0.7720
# Epoch 2/15
# 32/32 - 32s - loss: 0.4692 - accuracy: 0.7847 - val_loss: 0.4302 - val_accuracy: 0.7960
# Epoch 3/15
# 32/32 - 32s - loss: 0.4139 - accuracy: 0.8142 - val_loss: 0.4499 - val_accuracy: 0.7840
# Epoch 4/15
# 32/32 - 32s - loss: 0.3975 - accuracy: 0.8227 - val_loss: 0.3987 - val_accuracy: 0.8360
# Epoch 5/15
# 32/32 - 32s - loss: 0.3444 - accuracy: 0.8487 - val_loss: 0.3948 - val_accuracy: 0.8440
# Epoch 6/15
# 32/32 - 32s - loss: 0.3174 - accuracy: 0.8531 - val_loss: 0.3352 - val_accuracy: 0.8760
# Epoch 7/15
# 32/32 - 33s - loss: 0.2903 - accuracy: 0.8706 - val_loss: 0.3608 - val_accuracy: 0.8280
# Epoch 8/15
# 32/32 - 34s - loss: 0.2905 - accuracy: 0.8701 - val_loss: 0.4152 - val_accuracy: 0.8200
# 8/8 [==============================] - 1s 110ms/step - loss: 0.3352 - accuracy: 0.8760
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-16\assets
# --- Starting trial: run-17
# {'filter_size_1': 7, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 13s - loss: 0.8351 - accuracy: 0.6269 - val_loss: 0.9581 - val_accuracy: 0.5000
# Epoch 2/15
# 32/32 - 13s - loss: 0.5597 - accuracy: 0.7368 - val_loss: 0.4889 - val_accuracy: 0.7600
# Epoch 3/15
# 32/32 - 14s - loss: 0.4450 - accuracy: 0.7917 - val_loss: 0.4441 - val_accuracy: 0.7880
# Epoch 4/15
# 32/32 - 15s - loss: 0.4363 - accuracy: 0.7957 - val_loss: 0.5024 - val_accuracy: 0.7800
# Epoch 5/15
# 32/32 - 15s - loss: 0.4164 - accuracy: 0.8082 - val_loss: 0.5801 - val_accuracy: 0.7200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.4441 - accuracy: 0.7880
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-17\assets
# --- Starting trial: run-18
# {'filter_size_1': 7, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 14s - loss: 0.9769 - accuracy: 0.5994 - val_loss: 0.5727 - val_accuracy: 0.7120
# Epoch 2/15
# 32/32 - 14s - loss: 0.5253 - accuracy: 0.7507 - val_loss: 0.4874 - val_accuracy: 0.7560
# Epoch 3/15
# 32/32 - 13s - loss: 0.4793 - accuracy: 0.7832 - val_loss: 0.4577 - val_accuracy: 0.8080
# Epoch 4/15
# 32/32 - 13s - loss: 0.4402 - accuracy: 0.7932 - val_loss: 0.4157 - val_accuracy: 0.8360
# Epoch 5/15
# 32/32 - 13s - loss: 0.4070 - accuracy: 0.8057 - val_loss: 0.4646 - val_accuracy: 0.7920
# Epoch 6/15
# 32/32 - 13s - loss: 0.4207 - accuracy: 0.7967 - val_loss: 0.3795 - val_accuracy: 0.8240
# Epoch 7/15
# 32/32 - 11s - loss: 0.4035 - accuracy: 0.8152 - val_loss: 0.4289 - val_accuracy: 0.7880
# Epoch 8/15
# 32/32 - 13s - loss: 0.3712 - accuracy: 0.8287 - val_loss: 0.3934 - val_accuracy: 0.8040
# 8/8 [==============================] - 0s 58ms/step - loss: 0.3795 - accuracy: 0.8240
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-18\assets
# --- Starting trial: run-19
# {'filter_size_1': 7, 'filters_number': 32, 'filter_size_2': 5, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 20s - loss: 0.8525 - accuracy: 0.6464 - val_loss: 0.5531 - val_accuracy: 0.7080
# Epoch 2/15
# 32/32 - 20s - loss: 0.5317 - accuracy: 0.7552 - val_loss: 0.4712 - val_accuracy: 0.7720
# Epoch 3/15
# 32/32 - 16s - loss: 0.4848 - accuracy: 0.7772 - val_loss: 0.5600 - val_accuracy: 0.7480
# Epoch 4/15
# 32/32 - 19s - loss: 0.4315 - accuracy: 0.8062 - val_loss: 0.4450 - val_accuracy: 0.7800
# Epoch 5/15
# 32/32 - 19s - loss: 0.4118 - accuracy: 0.8092 - val_loss: 0.4094 - val_accuracy: 0.8360
# Epoch 6/15
# 32/32 - 19s - loss: 0.3800 - accuracy: 0.8157 - val_loss: 0.3977 - val_accuracy: 0.8280
# Epoch 7/15
# 32/32 - 19s - loss: 0.3727 - accuracy: 0.8247 - val_loss: 0.3921 - val_accuracy: 0.8040
# Epoch 8/15
# 32/32 - 19s - loss: 0.3650 - accuracy: 0.8317 - val_loss: 0.4371 - val_accuracy: 0.7840
# Epoch 9/15
# 32/32 - 18s - loss: 0.3380 - accuracy: 0.8442 - val_loss: 0.3691 - val_accuracy: 0.8000
# Epoch 10/15
# 32/32 - 19s - loss: 0.3272 - accuracy: 0.8447 - val_loss: 0.3354 - val_accuracy: 0.8480
# Epoch 11/15
# 32/32 - 19s - loss: 0.3047 - accuracy: 0.8671 - val_loss: 0.3799 - val_accuracy: 0.8200
# Epoch 12/15
# 32/32 - 19s - loss: 0.3067 - accuracy: 0.8596 - val_loss: 0.3516 - val_accuracy: 0.8240
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3354 - accuracy: 0.8480
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-19\assets
# --- Starting trial: run-20
# {'filter_size_1': 7, 'filters_number': 32, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 18s - loss: 0.7901 - accuracy: 0.6424 - val_loss: 0.6770 - val_accuracy: 0.5920
# Epoch 2/15
# 32/32 - 19s - loss: 0.5742 - accuracy: 0.7103 - val_loss: 0.5255 - val_accuracy: 0.7560
# Epoch 3/15
# 32/32 - 20s - loss: 0.4697 - accuracy: 0.7812 - val_loss: 0.4248 - val_accuracy: 0.8160
# Epoch 4/15
# 32/32 - 20s - loss: 0.4437 - accuracy: 0.7857 - val_loss: 0.4631 - val_accuracy: 0.7880
# Epoch 5/15
# 32/32 - 20s - loss: 0.4309 - accuracy: 0.7957 - val_loss: 0.4472 - val_accuracy: 0.7720
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4248 - accuracy: 0.8160
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-20\assets
# --- Starting trial: run-21
# {'filter_size_1': 7, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 28s - loss: 0.9254 - accuracy: 0.6434 - val_loss: 0.5878 - val_accuracy: 0.6920
# Epoch 2/15
# 32/32 - 26s - loss: 0.5448 - accuracy: 0.7433 - val_loss: 0.4911 - val_accuracy: 0.7760
# Epoch 3/15
# 32/32 - 26s - loss: 0.4673 - accuracy: 0.7742 - val_loss: 0.5455 - val_accuracy: 0.7480
# Epoch 4/15
# 32/32 - 26s - loss: 0.4420 - accuracy: 0.8017 - val_loss: 0.4930 - val_accuracy: 0.7480
# 8/8 [==============================] - 1s 80ms/step - loss: 0.4911 - accuracy: 0.7760
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-21\assets
# --- Starting trial: run-22
# {'filter_size_1': 7, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 29s - loss: 0.9668 - accuracy: 0.6399 - val_loss: 0.5156 - val_accuracy: 0.7320
# Epoch 2/15
# 32/32 - 24s - loss: 0.4838 - accuracy: 0.7742 - val_loss: 0.4502 - val_accuracy: 0.7920
# Epoch 3/15
# 32/32 - 26s - loss: 0.4327 - accuracy: 0.8137 - val_loss: 0.4207 - val_accuracy: 0.8000
# Epoch 4/15
# 32/32 - 27s - loss: 0.4058 - accuracy: 0.8162 - val_loss: 0.4093 - val_accuracy: 0.8400
# Epoch 5/15
# 32/32 - 26s - loss: 0.4303 - accuracy: 0.7907 - val_loss: 0.4058 - val_accuracy: 0.7960
# Epoch 6/15
# 32/32 - 27s - loss: 0.3990 - accuracy: 0.8137 - val_loss: 0.3824 - val_accuracy: 0.8200
# Epoch 7/15
# 32/32 - 27s - loss: 0.3495 - accuracy: 0.8427 - val_loss: 0.4139 - val_accuracy: 0.8280
# Epoch 8/15
# 32/32 - 26s - loss: 0.3344 - accuracy: 0.8521 - val_loss: 0.3940 - val_accuracy: 0.8200
# 8/8 [==============================] - 1s 96ms/step - loss: 0.3824 - accuracy: 0.8200 0s - loss: 0.3937 - accuracy
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-22\assets
# --- Starting trial: run-23
# {'filter_size_1': 7, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 256}
# Epoch 1/15
# 32/32 - 35s - loss: 0.8436 - accuracy: 0.5934 - val_loss: 0.5639 - val_accuracy: 0.7280
# Epoch 2/15
# 32/32 - 34s - loss: 0.5092 - accuracy: 0.7612 - val_loss: 0.4787 - val_accuracy: 0.7640
# Epoch 3/15
# 32/32 - 34s - loss: 0.4307 - accuracy: 0.8122 - val_loss: 0.4001 - val_accuracy: 0.8240
# Epoch 4/15
# 32/32 - 33s - loss: 0.4133 - accuracy: 0.8072 - val_loss: 0.4427 - val_accuracy: 0.8040
# Epoch 5/15
# 32/32 - 33s - loss: 0.4092 - accuracy: 0.8067 - val_loss: 0.4378 - val_accuracy: 0.8040
# 8/8 [==============================] - 1s 100ms/step - loss: 0.4001 - accuracy: 0.8240
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-23\assets
# --- Starting trial: run-24
# {'filter_size_1': 7, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 39s - loss: 1.1138 - accuracy: 0.5160 - val_loss: 0.6927 - val_accuracy: 0.5120
# Epoch 2/15
# 32/32 - 38s - loss: 0.6329 - accuracy: 0.6169 - val_loss: 0.6094 - val_accuracy: 0.6960
# Epoch 3/15
# 32/32 - 38s - loss: 0.5028 - accuracy: 0.7522 - val_loss: 0.4666 - val_accuracy: 0.7640
# Epoch 4/15
# 32/32 - 38s - loss: 0.4847 - accuracy: 0.7602 - val_loss: 0.4444 - val_accuracy: 0.7760
# Epoch 5/15
# 32/32 - 38s - loss: 0.4312 - accuracy: 0.7887 - val_loss: 0.4015 - val_accuracy: 0.8120
# Epoch 6/15
# 32/32 - 38s - loss: 0.4414 - accuracy: 0.7892 - val_loss: 0.4353 - val_accuracy: 0.7880
# Epoch 7/15
# 32/32 - 38s - loss: 0.4185 - accuracy: 0.7952 - val_loss: 0.3852 - val_accuracy: 0.8120
# Epoch 8/15
# 32/32 - 36s - loss: 0.4191 - accuracy: 0.7992 - val_loss: 0.4453 - val_accuracy: 0.7720
# Epoch 9/15
# 32/32 - 39s - loss: 0.4362 - accuracy: 0.7882 - val_loss: 0.3886 - val_accuracy: 0.7960
# 8/8 [==============================] - 1s 111ms/step - loss: 0.3852 - accuracy: 0.8120
# INFO:tensorflow:Assets written to: saved_models\Model 4_2\Run-24\assets

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 4_2/hparam_tuning"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-bdb01b93eb6bbd5d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-bdb01b93eb6bbd5d");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
