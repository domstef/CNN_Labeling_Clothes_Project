# %% [markdown]
# # Trousers and jeans model

# %% [markdown]
# 0 - Male trousers
# 1 - Female trousers
# 2 - Male jeans
# 3 - Female jeans
#
# This is a simple model - Conv2D -> Flatten - > Dense

# %% [markdown]
# # Import relevant libraries

# %%
import io
import itertools
import numpy as np
import sklearn.metrics
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the data

# %%
data_train = np.load(r"data/Trousers & Jeans - All - Train.npz")
data_validation = np.load(r"data/Trousers & Jeans - All - Validation.npz")
data_test = np.load(r"data/Trousers & Jeans - All - Test.npz")

print("Data train files: {}".format(data_train.files))
print("Size of the images: {}".format(data_train['images'].shape))
print("Size of the labels: {}".format(data_train['labels'].shape))
print("Unique values of the labels: {}".format(np.unique(data_train['labels'])))
n = np.random.randint(0, 4002)
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(data_train['images'][n])
print("The label of {}'th image is {}".format(n, data_train['labels'][n]))

n = np.random.randint(0, 4002)
ax2.imshow(data_train['images'][n])
print("The label of {}'th image is {}".format(n, data_train['labels'][n]))
# Out:
# Data train files: ['images', 'labels', 'genders']
# Size of the images: (4004, 120, 90, 3)
# Size of the labels: (4004,)
# Unique values of the labels: [0 1 2 3]
# The label of 1276'th image is 1
# The label of 698'th image is 3

# %%
images_train = data_train['images']
labels_train = data_train['labels']

images_val = data_validation['images']
labels_val = data_validation['labels']

images_test = data_test['images']
labels_test = data_test['labels']

# %%
images_train = images_train/255.0
images_val = images_val/255.0
images_test = images_test/255.0

# %% [markdown]
# # Training the models

# %%
EPOCHS = 15
BATCH_SIZE = 64 #power of 2
HP_LAMBDA = hp.HParam('lambda', hp.Discrete([5e-5, 1e-4, 5e-4,1e-3, 5e-3, 1e-2, 5e-2, 1e-1]))

METRIC_ACCURACY = "accuracy"

with tf.summary.create_file_writer(r'Logs/Model 6/hparam_tuning/').as_default():
    hp.hparams_config(
        hparams=[HP_LAMBDA],
        metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
    )

# %%
def plot_confusion_matrix(cm, class_names):
    """
    Returns a matplotlib figure containing the plotted confusion matrix.

    Args:
        cm (array, shape = [n, n]): a confusion matrix of integer classes
        class_names (array, shape = [n]): String names of the integer classes
    """
    figure = plt.figure(figsize=(12, 12))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    # Normalize the confusion matrix.
    cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return figure

# %%
def plot_to_image(figure):
    """Converts the matplotlib plot specified by 'figure' to a PNG image and
    returns it. The supplied figure is closed and inaccessible after this call."""
    # Save the plot to a PNG in memory.
    buf = io.BytesIO()
    plt.savefig(buf, format='png')
    # Closing the figure prevents it from being displayed directly inside
    # the notebook.
    plt.close(figure)
    buf.seek(0)
    # Convert PNG buffer to TF image
    image = tf.image.decode_png(buf.getvalue(), channels=4)
    # Add the batch dimension
    image = tf.expand_dims(image, 0)
    return image

# %%
def train_test_model(hparams, session_num):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(
            64, 
            3, 
            activation='relu',
            input_shape=(120,90,3),
            kernel_regularizer = tf.keras.regularizers.L2(hparams[HP_LAMBDA])),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Conv2D(
            64, 
            3, 
            activation='relu',
            kernel_regularizer = tf.keras.regularizers.L2(hparams[HP_LAMBDA])),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(4)
    ])
    
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, name = "sparse_categorical_crossentropy")
    model.compile(optimizer="adam", loss=loss_fn, metrics=['accuracy', 'sparse_categorical_crossentropy'])
    

    log_dir = "Logs\\Model 6\\fit\\" + "run {}".format(session_num)
    
  
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')
    
    def log_confusion_matrix(epoch, logs):
        
        test_pred_raw = model.predict(images_val)
        test_pred = np.argmax(test_pred_raw, axis=1)

        
        cm = sklearn.metrics.confusion_matrix(labels_val, test_pred)
       
        figure = plot_confusion_matrix(cm, class_names=['Trousers Male', 'Jeans Male', 'Trousers Female', 'Jeans Female'])
        cm_image = plot_to_image(figure)

        
        with file_writer_cm.as_default():
            tf.summary.image("Confusion Matrix", cm_image, step=epoch)
    
    
    
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch=0)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)
    

    
 
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor = 'val_sparse_categorical_crossentropy',
        mode = 'auto',
        min_delta = 0,
        patience = 2,
        verbose = 0, 
        restore_best_weights = True
    )
    

    model.fit(
        images_train,
        labels_train,
        epochs = EPOCHS,
        batch_size = BATCH_SIZE,
        callbacks = [tensorboard_callback, cm_callback, early_stopping],
        validation_data = (images_val,labels_val),
        verbose = 2
    )
    
    

    _, accuracy, crossentropy = model.evaluate(images_val,labels_val)
    

    model.save(r"saved_models\Model 6\Run-{}".format(session_num))
    
    return accuracy

# %%
def run(log_dir, hparams, session_num):
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step = 1)

# %%
session_num = 1

for lambda_reg in HP_LAMBDA.domain.values:
    
    hparams = {HP_LAMBDA: lambda_reg}
                   

    run_name = "run-%d" % session_num
    print('--- Starting trial: %s' % run_name)
    print({h.name: hparams[h] for h in hparams})
    run('Logs/Model 6/hparam_tuning/' + run_name, hparams, session_num)

    session_num += 1
# Out:
# --- Starting trial: run-1
# {'lambda': 5e-05}
# Epoch 1/15
# 63/63 - 22s - loss: 1.3577 - accuracy: 0.5077 - sparse_categorical_crossentropy: 3.0586 - val_loss: 1.0182 - val_accuracy: 0.5820 - val_sparse_categorical_crossentropy: 2.3335
# Epoch 2/15
# 63/63 - 21s - loss: 0.8597 - accuracy: 0.6568 - sparse_categorical_crossentropy: 1.7031 - val_loss: 0.9079 - val_accuracy: 0.6500 - val_sparse_categorical_crossentropy: 1.9878
# Epoch 3/15
# 63/63 - 21s - loss: 0.7553 - accuracy: 0.6998 - sparse_categorical_crossentropy: 1.4282 - val_loss: 0.8286 - val_accuracy: 0.6440 - val_sparse_categorical_crossentropy: 1.7624
# Epoch 4/15
# 63/63 - 20s - loss: 0.6805 - accuracy: 0.7343 - sparse_categorical_crossentropy: 1.3474 - val_loss: 0.7571 - val_accuracy: 0.7000 - val_sparse_categorical_crossentropy: 1.6201
# Epoch 5/15
# 63/63 - 20s - loss: 0.6144 - accuracy: 0.7567 - sparse_categorical_crossentropy: 1.2499 - val_loss: 0.7562 - val_accuracy: 0.6980 - val_sparse_categorical_crossentropy: 1.4393
# Epoch 6/15
# 63/63 - 20s - loss: 0.5825 - accuracy: 0.7672 - sparse_categorical_crossentropy: 1.1858 - val_loss: 0.7411 - val_accuracy: 0.7060 - val_sparse_categorical_crossentropy: 1.3582
# Epoch 7/15
# 63/63 - 20s - loss: 0.5177 - accuracy: 0.8002 - sparse_categorical_crossentropy: 1.0179 - val_loss: 0.7722 - val_accuracy: 0.7120 - val_sparse_categorical_crossentropy: 1.5255
# Epoch 8/15
# 63/63 - 21s - loss: 0.4653 - accuracy: 0.8254 - sparse_categorical_crossentropy: 0.9976 - val_loss: 0.7771 - val_accuracy: 0.7500 - val_sparse_categorical_crossentropy: 1.3352
# Epoch 9/15
# 63/63 - 21s - loss: 0.4237 - accuracy: 0.8422 - sparse_categorical_crossentropy: 0.9420 - val_loss: 0.7100 - val_accuracy: 0.7400 - val_sparse_categorical_crossentropy: 1.4719
# Epoch 10/15
# 63/63 - 21s - loss: 0.3865 - accuracy: 0.8589 - sparse_categorical_crossentropy: 0.9077 - val_loss: 0.7571 - val_accuracy: 0.7400 - val_sparse_categorical_crossentropy: 1.5215
# 16/16 [==============================] - 1s 36ms/step - loss: 0.7771 - accuracy: 0.7500 - sparse_categorical_crossentropy: 1.3352
# INFO:tensorflow:Assets written to: saved_models\Model 6\Run-1\assets
# --- Starting trial: run-2
# {'lambda': 0.0001}
# Epoch 1/15
# 63/63 - 20s - loss: 1.4833 - accuracy: 0.4590 - sparse_categorical_crossentropy: 4.5809 - val_loss: 1.0318 - val_accuracy: 0.5720 - val_sparse_categorical_crossentropy: 2.6934
# Epoch 2/15
# 63/63 - 20s - loss: 0.8747 - accuracy: 0.6454 - sparse_categorical_crossentropy: 1.9823 - val_loss: 0.9252 - val_accuracy: 0.6440 - val_sparse_categorical_crossentropy: 2.0702
# Epoch 3/15
# 63/63 - 20s - loss: 0.7523 - accuracy: 0.7030 - sparse_categorical_crossentropy: 1.6222 - val_loss: 0.8368 - val_accuracy: 0.6600 - val_sparse_categorical_crossentropy: 1.9111
# Epoch 4/15
# 63/63 - 20s - loss: 0.6671 - accuracy: 0.7378 - sparse_categorical_crossentropy: 1.5711 - val_loss: 0.8028 - val_accuracy: 0.6840 - val_sparse_categorical_crossentropy: 2.0600
# Epoch 5/15
# 63/63 - 20s - loss: 0.5918 - accuracy: 0.7700 - sparse_categorical_crossentropy: 1.2060 - val_loss: 0.8044 - val_accuracy: 0.7140 - val_sparse_categorical_crossentropy: 1.7953
# Epoch 6/15
# 63/63 - 20s - loss: 0.5617 - accuracy: 0.7770 - sparse_categorical_crossentropy: 1.2926 - val_loss: 0.7393 - val_accuracy: 0.7240 - val_sparse_categorical_crossentropy: 1.6727
# Epoch 7/15
# 63/63 - 20s - loss: 0.5116 - accuracy: 0.7995 - sparse_categorical_crossentropy: 1.3345 - val_loss: 0.7308 - val_accuracy: 0.7120 - val_sparse_categorical_crossentropy: 1.7314
# Epoch 8/15
# 63/63 - 19s - loss: 0.4794 - accuracy: 0.8214 - sparse_categorical_crossentropy: 1.2164 - val_loss: 0.7558 - val_accuracy: 0.7540 - val_sparse_categorical_crossentropy: 1.8060
# 16/16 [==============================] - 1s 35ms/step - loss: 0.7393 - accuracy: 0.7240 - sparse_categorical_crossentropy: 1.6727
# INFO:tensorflow:Assets written to: saved_models\Model 6\Run-2\assets
# --- Starting trial: run-3
# {'lambda': 0.0005}
# Epoch 1/15
# 63/63 - 20s - loss: 1.3446 - accuracy: 0.4868 - sparse_categorical_crossentropy: 3.9090 - val_loss: 1.0494 - val_accuracy: 0.5580 - val_sparse_categorical_crossentropy: 3.0050
# Epoch 2/15
# 63/63 - 20s - loss: 0.9101 - accuracy: 0.6399 - sparse_categorical_crossentropy: 2.1329 - val_loss: 0.9634 - val_accuracy: 0.6400 - val_sparse_categorical_crossentropy: 2.3586
# Epoch 3/15
# 63/63 - 20s - loss: 0.7972 - accuracy: 0.6916 - sparse_categorical_crossentropy: 1.8629 - val_loss: 0.8605 - val_accuracy: 0.6440 - val_sparse_categorical_crossentropy: 1.8107
# Epoch 4/15
# 63/63 - 20s - loss: 0.7033 - accuracy: 0.7278 - sparse_categorical_crossentropy: 1.5220 - val_loss: 0.8062 - val_accuracy: 0.7220 - val_sparse_categorical_crossentropy: 2.1172
# Epoch 5/15
# 63/63 - 20s - loss: 0.6275 - accuracy: 0.7575 - sparse_categorical_crossentropy: 1.4450 - val_loss: 0.7718 - val_accuracy: 0.7000 - val_sparse_categorical_crossentropy: 1.5977
# Epoch 6/15
# 63/63 - 20s - loss: 0.5426 - accuracy: 0.7952 - sparse_categorical_crossentropy: 1.1704 - val_loss: 0.7260 - val_accuracy: 0.7380 - val_sparse_categorical_crossentropy: 1.5495
# Epoch 7/15
# 63/63 - 20s - loss: 0.5325 - accuracy: 0.7985 - sparse_categorical_crossentropy: 1.1404 - val_loss: 0.7066 - val_accuracy: 0.7500 - val_sparse_categorical_crossentropy: 1.4382
# Epoch 8/15
# 63/63 - 20s - loss: 0.4800 - accuracy: 0.8214 - sparse_categorical_crossentropy: 1.0779 - val_loss: 0.7319 - val_accuracy: 0.7680 - val_sparse_categorical_crossentropy: 1.5266
# Epoch 9/15
# 63/63 - 21s - loss: 0.4132 - accuracy: 0.8514 - sparse_categorical_crossentropy: 0.8978 - val_loss: 0.7816 - val_accuracy: 0.7180 - val_sparse_categorical_crossentropy: 1.6663
# 16/16 [==============================] - 1s 39ms/step - loss: 0.7066 - accuracy: 0.7500 - sparse_categorical_crossentropy: 1.4382
# INFO:tensorflow:Assets written to: saved_models\Model 6\Run-3\assets
# --- Starting trial: run-4
# {'lambda': 0.001}
# Epoch 1/15
# 63/63 - 21s - loss: 1.5022 - accuracy: 0.4705 - sparse_categorical_crossentropy: 4.6192 - val_loss: 1.0807 - val_accuracy: 0.5860 - val_sparse_categorical_crossentropy: 2.6816
# Epoch 2/15
# 63/63 - 21s - loss: 0.9079 - accuracy: 0.6568 - sparse_categorical_crossentropy: 2.5056 - val_loss: 0.9302 - val_accuracy: 0.6460 - val_sparse_categorical_crossentropy: 2.7176
# Epoch 3/15
# 63/63 - 21s - loss: 0.7902 - accuracy: 0.6966 - sparse_categorical_crossentropy: 1.9510 - val_loss: 0.8942 - val_accuracy: 0.6240 - val_sparse_categorical_crossentropy: 2.0251
# Epoch 4/15
# 63/63 - 21s - loss: 0.7176 - accuracy: 0.7170 - sparse_categorical_crossentropy: 1.7583 - val_loss: 0.8799 - val_accuracy: 0.6420 - val_sparse_categorical_crossentropy: 2.2453
# Epoch 5/15
# 63/63 - 20s - loss: 0.6576 - accuracy: 0.7458 - sparse_categorical_crossentropy: 1.5994 - val_loss: 0.8421 - val_accuracy: 0.6860 - val_sparse_categorical_crossentropy: 1.9113
# Epoch 6/15
# 63/63 - 20s - loss: 0.6334 - accuracy: 0.7590 - sparse_categorical_crossentropy: 1.5979 - val_loss: 0.8417 - val_accuracy: 0.6560 - val_sparse_categorical_crossentropy: 2.1568
# Epoch 7/15
# 63/63 - 20s - loss: 0.6121 - accuracy: 0.7647 - sparse_categorical_crossentropy: 1.5222 - val_loss: 0.7794 - val_accuracy: 0.7220 - val_sparse_categorical_crossentropy: 1.8321
# Epoch 8/15
# 63/63 - 20s - loss: 0.5562 - accuracy: 0.7960 - sparse_categorical_crossentropy: 1.3709 - val_loss: 0.8964 - val_accuracy: 0.6920 - val_sparse_categorical_crossentropy: 2.2519
# Epoch 9/15
# 63/63 - 21s - loss: 0.5009 - accuracy: 0.8177 - sparse_categorical_crossentropy: 1.1842 - val_loss: 0.7504 - val_accuracy: 0.7220 - val_sparse_categorical_crossentropy: 1.7102
# Epoch 10/15
# 63/63 - 21s - loss: 0.4619 - accuracy: 0.8369 - sparse_categorical_crossentropy: 1.1281 - val_loss: 0.7110 - val_accuracy: 0.7620 - val_sparse_categorical_crossentropy: 1.5307
# Epoch 11/15
# 63/63 - 21s - loss: 0.4161 - accuracy: 0.8584 - sparse_categorical_crossentropy: 1.0811 - val_loss: 0.7566 - val_accuracy: 0.7580 - val_sparse_categorical_crossentropy: 1.6869
# Epoch 12/15
# 63/63 - 21s - loss: 0.4110 - accuracy: 0.8546 - sparse_categorical_crossentropy: 1.0586 - val_loss: 0.7643 - val_accuracy: 0.7460 - val_sparse_categorical_crossentropy: 1.8060
# 16/16 [==============================] - 1s 36ms/step - loss: 0.7110 - accuracy: 0.7620 - sparse_categorical_crossentropy: 1.5307
# INFO:tensorflow:Assets written to: saved_models\Model 6\Run-4\assets
# --- Starting trial: run-5
# {'lambda': 0.005}
# Epoch 1/15
# 63/63 - 21s - loss: 1.6322 - accuracy: 0.4773 - sparse_categorical_crossentropy: 3.3240 - val_loss: 1.2563 - val_accuracy: 0.5480 - val_sparse_categorical_crossentropy: 2.4259
# Epoch 2/15
# 63/63 - 21s - loss: 1.0397 - accuracy: 0.6359 - sparse_categorical_crossentropy: 1.5038 - val_loss: 1.0742 - val_accuracy: 0.6100 - val_sparse_categorical_crossentropy: 1.4193
# Epoch 3/15
# 63/63 - 21s - loss: 0.9088 - accuracy: 0.6921 - sparse_categorical_crossentropy: 1.2422 - val_loss: 1.0236 - val_accuracy: 0.6360 - val_sparse_categorical_crossentropy: 1.5481
# Epoch 4/15
# 63/63 - 21s - loss: 0.8356 - accuracy: 0.7260 - sparse_categorical_crossentropy: 1.2104 - val_loss: 0.9258 - val_accuracy: 0.7040 - val_sparse_categorical_crossentropy: 1.2802
# Epoch 5/15
# 63/63 - 21s - loss: 0.7871 - accuracy: 0.7393 - sparse_categorical_crossentropy: 1.1676 - val_loss: 1.0383 - val_accuracy: 0.6600 - val_sparse_categorical_crossentropy: 1.6170
# Epoch 6/15
# 63/63 - 20s - loss: 0.7133 - accuracy: 0.7717 - sparse_categorical_crossentropy: 1.0850 - val_loss: 0.8728 - val_accuracy: 0.6780 - val_sparse_categorical_crossentropy: 1.2202
# Epoch 7/15
# 63/63 - 20s - loss: 0.6821 - accuracy: 0.7880 - sparse_categorical_crossentropy: 1.1062 - val_loss: 0.9694 - val_accuracy: 0.7060 - val_sparse_categorical_crossentropy: 1.2591
# Epoch 8/15
# 63/63 - 20s - loss: 0.6365 - accuracy: 0.7967 - sparse_categorical_crossentropy: 0.9904 - val_loss: 0.9284 - val_accuracy: 0.6840 - val_sparse_categorical_crossentropy: 1.3607
# 16/16 [==============================] - 1s 35ms/step - loss: 0.8728 - accuracy: 0.6780 - sparse_categorical_crossentropy: 1.2202
# INFO:tensorflow:Assets written to: saved_models\Model 6\Run-5\assets
# --- Starting trial: run-6
# {'lambda': 0.01}
# Epoch 1/15
# 63/63 - 21s - loss: 1.7679 - accuracy: 0.5070 - sparse_categorical_crossentropy: 4.1066 - val_loss: 1.2946 - val_accuracy: 0.5900 - val_sparse_categorical_crossentropy: 2.7472
# Epoch 2/15
# 63/63 - 20s - loss: 1.1432 - accuracy: 0.6381 - sparse_categorical_crossentropy: 2.4172 - val_loss: 1.1447 - val_accuracy: 0.6520 - val_sparse_categorical_crossentropy: 2.6151
# Epoch 3/15
# 63/63 - 20s - loss: 1.0149 - accuracy: 0.6853 - sparse_categorical_crossentropy: 1.8259 - val_loss: 1.0498 - val_accuracy: 0.6580 - val_sparse_categorical_crossentropy: 1.9216
# Epoch 4/15
# 63/63 - 20s - loss: 0.9349 - accuracy: 0.7175 - sparse_categorical_crossentropy: 1.5476 - val_loss: 1.1237 - val_accuracy: 0.6400 - val_sparse_categorical_crossentropy: 2.1967
# Epoch 5/15
# 63/63 - 20s - loss: 0.8746 - accuracy: 0.7395 - sparse_categorical_crossentropy: 1.5321 - val_loss: 0.9907 - val_accuracy: 0.6820 - val_sparse_categorical_crossentropy: 2.2228
# 16/16 [==============================] - 1s 35ms/step - loss: 1.0498 - accuracy: 0.6580 - sparse_categorical_crossentropy: 1.9216
# INFO:tensorflow:Assets written to: saved_models\Model 6\Run-6\assets
# --- Starting trial: run-7
# {'lambda': 0.05}
# Epoch 1/15
# 63/63 - 20s - loss: 3.2889 - accuracy: 0.4695 - sparse_categorical_crossentropy: 4.4940 - val_loss: 2.1730 - val_accuracy: 0.5300 - val_sparse_categorical_crossentropy: 2.9846
# Epoch 2/15
# 63/63 - 20s - loss: 1.8376 - accuracy: 0.6314 - sparse_categorical_crossentropy: 2.3043 - val_loss: 1.7145 - val_accuracy: 0.6280 - val_sparse_categorical_crossentropy: 2.2146
# Epoch 3/15
# 63/63 - 20s - loss: 1.4854 - accuracy: 0.6731 - sparse_categorical_crossentropy: 1.8119 - val_loss: 1.4736 - val_accuracy: 0.6220 - val_sparse_categorical_crossentropy: 1.9616
# Epoch 4/15
# 63/63 - 20s - loss: 1.2652 - accuracy: 0.6941 - sparse_categorical_crossentropy: 1.5678 - val_loss: 1.3031 - val_accuracy: 0.6420 - val_sparse_categorical_crossentropy: 1.8031
# Epoch 5/15
# 63/63 - 20s - loss: 1.1079 - accuracy: 0.7060 - sparse_categorical_crossentropy: 1.4800 - val_loss: 1.1370 - val_accuracy: 0.6900 - val_sparse_categorical_crossentropy: 1.5388
# Epoch 6/15
# 63/63 - 21s - loss: 0.9788 - accuracy: 0.7375 - sparse_categorical_crossentropy: 1.5878 - val_loss: 1.0395 - val_accuracy: 0.7180 - val_sparse_categorical_crossentropy: 1.8352
# Epoch 7/15
# 63/63 - 20s - loss: 0.8968 - accuracy: 0.7443 - sparse_categorical_crossentropy: 1.5294 - val_loss: 1.0043 - val_accuracy: 0.7300 - val_sparse_categorical_crossentropy: 1.9201
# 16/16 [==============================] - 1s 35ms/step - loss: 1.1370 - accuracy: 0.6900 - sparse_categorical_crossentropy: 1.5388
# INFO:tensorflow:Assets written to: saved_models\Model 6\Run-7\assets
# --- Starting trial: run-8
# {'lambda': 0.1}
# Epoch 1/15
# 63/63 - 20s - loss: 4.6976 - accuracy: 0.4773 - sparse_categorical_crossentropy: 4.7271 - val_loss: 2.6179 - val_accuracy: 0.5360 - val_sparse_categorical_crossentropy: 4.6136
# Epoch 2/15
# 63/63 - 20s - loss: 2.0452 - accuracy: 0.6404 - sparse_categorical_crossentropy: 2.7908 - val_loss: 1.8182 - val_accuracy: 0.6120 - val_sparse_categorical_crossentropy: 3.3937
# Epoch 3/15
# 63/63 - 20s - loss: 1.5366 - accuracy: 0.6791 - sparse_categorical_crossentropy: 2.4737 - val_loss: 1.4713 - val_accuracy: 0.6460 - val_sparse_categorical_crossentropy: 2.7461
# Epoch 4/15
# 63/63 - 20s - loss: 1.2559 - accuracy: 0.6988 - sparse_categorical_crossentropy: 2.1985 - val_loss: 1.2377 - val_accuracy: 0.6920 - val_sparse_categorical_crossentropy: 2.4903
# Epoch 5/15
# 63/63 - 21s - loss: 1.0735 - accuracy: 0.7243 - sparse_categorical_crossentropy: 2.0941 - val_loss: 1.1192 - val_accuracy: 0.6900 - val_sparse_categorical_crossentropy: 2.2351
# Epoch 6/15
# 63/63 - 21s - loss: 0.9566 - accuracy: 0.7375 - sparse_categorical_crossentropy: 1.8993 - val_loss: 1.0315 - val_accuracy: 0.6740 - val_sparse_categorical_crossentropy: 2.4516
# Epoch 7/15
# 63/63 - 21s - loss: 0.8441 - accuracy: 0.7692 - sparse_categorical_crossentropy: 1.7396 - val_loss: 0.9641 - val_accuracy: 0.7100 - val_sparse_categorical_crossentropy: 2.3331
# 16/16 [==============================] - 1s 36ms/step - loss: 1.1192 - accuracy: 0.6900 - sparse_categorical_crossentropy: 2.2351
# INFO:tensorflow:Assets written to: saved_models\Model 6\Run-8\assets

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 6/hparam_tuning"
# Out:
#       <iframe id="tensorboard-frame-d35d522dd89e6c05" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d35d522dd89e6c05");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
